# %% [markdown]
# <h1><center>CS598 Deep Learning for Healthcare Spring 2023<br>Paper Reproduction Project</center></h1>

# %% [markdown]
# <h3><center>Gilberto Ramirez and Jay Kakwani<br><span style="font-family:monospace;">{ger6, kakwani2}@illinois.edu</span><br><font color="lightgrey">Group ID: 27 | Paper ID: 181</font></center></h3>

# %% [markdown]
# In this project, we aim to reproduce the paper [*Learning Task for Multitask Learning: Heterogeneous Patient Populations in the ICU* by (Suresh et al, 2018)](https://arxiv.org/abs/1806.02878). In this paper, the authors propose a novel two-step pipeline to predict in-hospital mortality across patient populations with different characteristics. The first step of the pipeline divides patients into relevant non-overlapping cohorts in an unsupervised way using a long short-term memory (LSTM) autoencoder followed by a Gaussian Mixture Model (GMM). The second step of the pipeline predicts in-hospital mortality for each patient cohort identified in the previous step using an LSTM based multi-task learning model where every cohort is considered a different task.
# The paper claims that by applying this pipeline there will be better predictive results when compared to a model applied to the aggregate population using a single task learning model. According to the authors, the better performance given by this pipeline is due to the combination of a multi-task learning model leveraging shared knowledge across distinct patient groups and the way how those groups were created, i.e., identification using a data-driven method rather than relying on domain knowledge or auxiliary labels.

# %% [markdown]
# ## 1. Data

# %% [markdown]
# This paper uses the publicly available [MIMIC-III database](https://www.nature.com/articles/sdata201635) which contains clinical data in a critical care setting. After reviewing the paper in detail, we decided to use [MIMIC-Extract](https://arxiv.org/abs/1907.08322), an open source pipeline by (Wang et al., 2020) for transforming the raw EHR data into usable [Pandas](https://pandas.pydata.org/) dataframes containing hourly time series of vitals and laboratory measurements after performing unit conversion, outlier handling, and aggregation of semantically similar features.
#
# Unfortunately, the MIMIC-Extract pipeline misses two features the [paper code](https://github.com/mit-caml/multitask-patients) makes use of:
# * `timecmo_chart` which indicates the timestamp of a patient after being declared in CMO (Comfort Measures Only) state. This feature comes from a MIMIC-III concept table called `code_status`.
# * `sapsii` which contains the SAPS (Simplified Acute Physiology Score) II for the patient. This feature comes from another MIMIC-III concept table called `sapsii`.
#
# As a result, there are three data files needed to run this notebook:
# * `all_hourly_data.h5`, an HDF file resulting from running the MIMIC-Extract pipeline which is publicly available in GCP using [this link](https://console.cloud.google.com/storage/browser/mimic_extract) and referenced in the [MIMIC-Extract github repo](https://github.com/MLforHealth/MIMIC_Extract).
# * `code_status.csv`, a CSV file holding the MIMIC concept table `CODE_STATUS` that can be generated following the instructions in [this link within the MIT-LCP github repo](https://github.com/MIT-LCP/mimic-code/tree/main/mimic-iii/concepts#generating-the-concepts-in-postgresql).
# * `sapsii.csv`, a CSV file holding the MIMIC concept table `SAPSII` that can be generated following the instructions in [this link within the MIT-LCP github repo](https://github.com/MIT-LCP/mimic-code/tree/main/mimic-iii/concepts#generating-the-concepts-in-postgresql).
#
# The functions used in this notebook assume the three files listed above are in the folder `../data/` by default. However, location can be changed using arguments to the functions that process the data.
#
# All code needed to replicate the paper is in [our github repo](https://github.com/ger6-illini/dl4h-sp23-team27-project) inside a Python module called `mtl_patients`.
#
# The first function from that module we will start using is `get_summaries()`. This function returns three summaries as dataframes:
# 1. A summary providing some statistics of all patients broken by careunit.
# 2. A summary providing some statistics of all patients broken by SAPS-II score quartile.
# 3. A summary providing some statistics of the 29 distinct physiological measurements used in the paper.
#
# These summaries need two arguments to be created:
# * `cutoff_hours` (default 24) which is the minimum number of hours a patient needs to stay in the ICU to be considered part of a cohort.
# * `gap_hours` (default 12) which is the number of hours between the end of `cutoff_hours` and the moment a model can start making a mortality prediction.
#
# The importance of these two arguments is his impact in the exception criteria used in the paper. In particular, the paper:
# 1. Excludes all patients that met the in-hospital mortality criteria before `cutoff period` + `gap period`.
# 2. Excludes patients that were discharged before `cutoff period` + `gap period`.
#
# The in-hospital mortality criteria used in the paper is an extended one and not just considers patients who died but also patients with a CMO (Comfort Measures Only) note. That is considered in the summaries creation as well.

# %% [markdown]
# ### 1.1. Summaries, 24 hours (cutoff period) + 12 hours (gap period)

# %% [markdown]
# Now let's run the `get_summaries()` function with `cutoff_hours` = 24 and `gap_hours` = 12:

# %%
# %load_ext autoreload
# %autoreload 2

import numpy as np
import pandas as pd

import sys
pathname = "../code/"
if pathname not in sys.path:
    sys.path.append("../code/")
pd.options.display.max_rows = 999

from mtl_patients import get_summaries
# Out:
# 2023-04-06 15:44:35.609940: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
# %%time
pat_summ_24_by_cu_df, pat_summ_24_by_sapsiiq_df, vitals_labs_summ_24_df = get_summaries(cutoff_hours=24, gap_hours=12)
# Out:
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Creating summaries
# --------------------------------------------------------------------------------
#     Loading data from MIMIC-Extract pipeline...
#     Adding SAPS II score to static dataset...
#     Adding mortality columns to static dataset...
#     Merging dataframes to create X_full...
#     Creating summary by careunit...
#     Creating summary by SAPS II score quartile...
#     Creating summary by vitals/labs...
#     Done!
# CPU times: user 7.37 s, sys: 2.11 s, total: 9.48 s
# Wall time: 9.82 s

# %% [markdown]
# Let's now display the resulting summaries one at a time.

# %% [markdown]
# #### 1.1.1. Data summary by patients in each intensive care unit (ICU)

# %%
pat_summ_24_by_cu_df
# Out:
#               N     n  Class Imbalance  Age (Mean)  Gender (Male)
# Careunit
# CCU        4907   344            0.070       82.56           0.58
# CSRU       6971   139            0.020       69.49           0.67
# MICU      11403  1138            0.100       77.97           0.51
# SICU       5187   409            0.079       72.65           0.52
# TSICU      4245   291            0.069       67.20           0.61
# Overall   32713  2321            0.071       74.61           0.57

# %% [markdown]
# In the previous summary, patients were broken in groups where each group is one of five careunits where patients were first admitted:
# * CCU: Coronary Care Unit
# * CSRU: Cardiac Surgery Recovery Unit
# * MICU: Medical Intensive Care Unit
# * SICU: Surgical Intensive Care Unit
# * TSICU: Trauma Surgical Intensive Care Unit
#
# In addition, an overall group was also added. The statistics provided by the summary are:
# * `N`: The number of samples (patients) in the group.
# * `n`: The number of samples (patients) meeting the in-hospital mortality criteria defined in the paper: patient died or had a note of "Do Not Resuscitate" (DNR) or had a note of "Comfort Measures Only" (CMO).
# * `Class Imbalance`: Ratio of patients meeting the in-hospital mortality criteria defined in the paper, i.e., $\dfrac{\text{n}}{\text{N}}$.
# * `Age (Mean)`: Mean age of patients for each group in years.
# * `Gender (Male)`: Ratio of patients that are males.
#
# This summary was prepared to match Table 1 in the original paper. There are differences between both that can be attributed to the way how data was preprocessed by MIMIC-Extract when compared to the preprocessing done by the authors back in 2018, before MIMIC-Extract became available, and that was not made available by the authors in [their code](https://github.com/mit-caml/multitask-patients).

# %% [markdown]
# #### 1.1.2. Data summary by patients in each SAPS-II score quartile

# %%
pat_summ_24_by_sapsiiq_df
# Out:
#                       N     n  Class Imbalance  Age (Mean)  Gender (Male)  \
# SAPS II Quartile
# 0                  7099    62            0.009       45.69           0.61
# 1                 10033   259            0.026       68.94           0.58
# 2                  8127   552            0.068       86.52           0.55
# 3                  7454  1448            0.194       96.80           0.54
# Overall           32713  2321            0.071       74.61           0.57
#
#                   SAPS II (Min)  SAPS II (Mean)  SAPS II (Max)
# SAPS II Quartile
# 0                             0           16.61             22
# 1                            23           27.74             32
# 2                            33           36.72             41
# 3                            42           51.42            118
# Overall                       0           32.95            118

# %% [markdown]
# In the previous summary, patients were broken based on the quartile of the SAPS-II score assigned to them. As it can be seen, the four quartiles have the ranges $[0, 22], [23, 32], [33, 41], [42, 118] $. This was included in the authors code but not in the paper. It seems the class imbalance might have been the primary reason. As it is evident from the summary, most of the patients are in quartile $3$ since they are in an ICU and is expected their values are on the high side.

# %% [markdown]
# #### 1.1.3. Data summary for physiological measurements

# %%
vitals_labs_summ_24_df
# Out:
#                                min     avg      max     std        N   pres.
# variable
# anion gap                     5.00   13.62    50.00    3.84   178506  0.0832
# bicarbonate                   0.00   24.32    53.00    4.68   187223  0.0873
# blood urea nitrogen           0.00   26.07   250.00   21.63   189120  0.0882
# chloride                     50.00  105.19   175.00    6.26   205674  0.0959
# creatinine                    0.10    1.39    46.60    1.48   189944  0.0886
# diastolic blood pressure      0.00   60.95   307.00   14.08  1866709  0.8703
# fraction inspired oxygen      0.21    0.53     1.00    0.19    95643  0.0446
# glascow coma scale total      3.00   12.59    15.00    3.50   367332  0.1713
# glucose                      33.00  140.03  1591.00   56.29   502487  0.2343
# heart rate                    0.00   84.88   300.00   17.13  1927016  0.8985
# hematocrit                    0.00   30.97    71.70    5.30   247725  0.1155
# hemoglobin                    0.00   10.63    22.10    1.88   199930  0.0932
# lactate                       0.40    2.51    30.00    2.36    58088  0.0271
# magnesium                     0.00    2.05    20.00    0.41   176416  0.0823
# mean blood pressure          14.00   79.46   330.00   15.42  1857529  0.8661
# oxygen saturation             0.00   96.76   100.00    3.42  1842683  0.8591
# partial thromboplastin time  18.80   41.06   150.00   24.43   131651  0.0614
# ph                            6.50    7.38     8.40    0.07   195046  0.0909
# phosphate                     0.50    3.46    20.00    1.39   115163  0.0537
# platelets                     0.00  204.82  2000.00  113.15   181464  0.0846
# potassium                     0.80    4.12    12.00    0.64   229886  0.1072
# prothrombin time inr          0.50    1.51    88.80    1.21   125119  0.0583
# prothrombin time pt           2.39   15.92   150.00    6.86   125094  0.0583
# respiratory rate              0.00   19.09   300.00    5.70  1896818  0.8844
# sodium                       50.00  138.58   225.00    5.23   217204  0.1013
# systolic blood pressure       0.00  122.00   311.00   21.85  1867146  0.8705
# temperature                  26.00   36.98    42.22    0.77   635055  0.2961
# weight                        0.00   83.25   250.00   23.39    59919  0.0279
# white blood cell count        0.10   11.88   939.00    9.64   173862  0.0811

# %% [markdown]
# In the previous summary, all vitals and lab measurements selected in the paper (29 in total) are listed with relevant statistics associated to it:
# * `min` representing the minimum of the measurement observed in the vitals/labs.
# * `avg` representing the average of the measurement observed in the vitals/labs.
# * `max` representing the maximum of the measurement observed in the vitals/labs.
# * `std` representing the standard deviation of the measurement observed in the vitals/labs.
# * `N` representing the number of non `NaN` samples for the specific vital/lab measurement.
# * `pres.` representing the portion of all possible hours across all patients, admissions, and ICU stays where at least one of the 104 vitals/labs measurements in the original MIMIC-Extract pipeline was taken.
#
# All these measurements are based on the `vitals_labs_mean` dataframe in the MIMIC-Extract pipeline which provides average of vitals/labs on a per hour basis for each patient after going into an ICU.

# %% [markdown]
# ### 1.2. Summaries, 48 hours (cutoff period) + 24 hours (gap period)

# %% [markdown]
# Now let's run the `get_summaries()` function with `cutoff_hours` = 48 and `gap_hours` = 24:

# %%
# %%time
pat_summ_48_by_cu_df, pat_summ_48_by_sapsiiq_df, vitals_labs_summ_48_df = get_summaries(cutoff_hours=48, gap_hours=24)
# Out:
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Creating summaries
# --------------------------------------------------------------------------------
#     Loading data from MIMIC-Extract pipeline...
#     Adding SAPS II score to static dataset...
#     Adding mortality columns to static dataset...
#     Merging dataframes to create X_full...
#     Creating summary by careunit...
#     Creating summary by SAPS II score quartile...
#     Creating summary by vitals/labs...
#     Done!
# CPU times: user 6.7 s, sys: 1.47 s, total: 8.17 s
# Wall time: 8.4 s

# %% [markdown]
# #### 1.2.1. Data summary by patients in each intensive care unit (ICU)

# %%
pat_summ_48_by_cu_df
# Out:
#               N     n  Class Imbalance  Age (Mean)  Gender (Male)
# Careunit
# CCU        4403   258            0.059       83.28           0.58
# CSRU       6865   110            0.016       69.44           0.67
# MICU      10409   866            0.083       78.47           0.51
# SICU       4815   303            0.063       72.88           0.51
# TSICU      3950   202            0.051       67.35           0.60
# Overall   30442  1739            0.057       74.80           0.57

# %% [markdown]
# #### 1.2.2. Data summary by patients in each SAPS-II score quartile

# %%
pat_summ_48_by_sapsiiq_df
# Out:
#                       N     n  Class Imbalance  Age (Mean)  Gender (Male)  \
# SAPS II Quartile
# 0                  6340    47            0.007       45.90           0.61
# 1                  9402   203            0.022       68.66           0.58
# 2                  7766   439            0.057       86.51           0.55
# 3                  6934  1050            0.151       96.45           0.53
# Overall           30442  1739            0.057       74.80           0.57
#
#                   SAPS II (Min)  SAPS II (Mean)  SAPS II (Max)
# SAPS II Quartile
# 0                             0           16.65             22
# 1                            23           27.78             32
# 2                            33           36.72             41
# 3                            42           51.00            110
# Overall                       0           33.03            110

# %% [markdown]
# #### 1.2.3. Data summary for physiological measurements

# %%
vitals_labs_summ_48_df
# Out:
#                                min     avg      max     std        N   pres.
# variable
# anion gap                     5.00   13.51    50.00    3.72   170026  0.0826
# bicarbonate                   0.00   24.41    53.00    4.63   178469  0.0867
# blood urea nitrogen           0.00   26.02   250.00   21.60   180302  0.0876
# chloride                     50.00  105.19   175.00    6.22   196370  0.0954
# creatinine                    0.10    1.38    46.60    1.48   181105  0.0880
# diastolic blood pressure      0.00   60.96   307.00   14.04  1797292  0.8729
# fraction inspired oxygen      0.21    0.53     1.00    0.19    91864  0.0446
# glascow coma scale total      3.00   12.67    15.00    3.42   352443  0.1712
# glucose                      33.00  139.72  1591.00   55.49   485940  0.2360
# heart rate                    0.00   84.89   300.00   17.00  1854010  0.9005
# hematocrit                    0.00   30.88    71.70    5.25   237820  0.1155
# hemoglobin                    0.00   10.60    22.10    1.86   191517  0.0930
# lactate                       0.40    2.37    30.00    2.09    54344  0.0264
# magnesium                     0.00    2.05    20.00    0.41   168654  0.0819
# mean blood pressure          14.00   79.53   330.00   15.39  1788354  0.8686
# oxygen saturation             0.00   96.78   100.00    3.32  1775192  0.8622
# partial thromboplastin time  18.80   40.93   150.00   24.21   125686  0.0610
# ph                            6.50    7.39     8.40    0.07   187767  0.0912
# phosphate                     0.50    3.44    20.00    1.36   109620  0.0532
# platelets                     0.00  204.63  2000.00  113.46   173311  0.0842
# potassium                     0.80    4.12    12.00    0.63   221276  0.1075
# prothrombin time inr          0.50    1.49    88.80    1.16   119240  0.0579
# prothrombin time pt           2.39   15.82   150.00    6.60   119217  0.0579
# respiratory rate              0.00   19.11   300.00    5.68  1825409  0.8866
# sodium                       50.00  138.55   225.00    5.17   207515  0.1008
# systolic blood pressure       0.00  122.15   311.00   21.77  1797698  0.8731
# temperature                  26.00   36.99    42.22    0.77   613308  0.2979
# weight                        0.00   83.40   250.00   23.33    56993  0.0277
# white blood cell count        0.10   11.85   939.00    9.56   166030  0.0806

# %% [markdown]
# ## 2. Discovering Patient Cohorts

# %% [markdown]
# The paper uses a two-step pipeline to: 1) identify relevant patient cohorts, and 2) use those relevant cohorts as separate tasks in a multi-lask learning framework to predict in-hospital mortality. In this section, we will focus on the first step of the pipeline, i.e., patient cohort discovery.

# %% [markdown]
# In order to identify meaningful patient cohorts, the paper proposes to process the raw patient data in such a way that the result is a 3D matrix of shape $(P \times T \times F)$ where $P$ represents the number of patients, $T$ the number of timesteps, and $F$ the number of features as depicted in the figure below (in blue) which is partially based on Figure 2 of the original paper. All numbers shown in the figure below correspond to a specific experiment published in the paper in which the observation window is limited to the first $24$ hours (cutoff period) after a patient goes into a careunit and there is a gap of $12$ hours (gap period) between the end of the observation window and the beginning of the prediction window where the prediction task is in-hospital mortality.
#
# Preparation of the data to get the 3D (blue) matrix is performed by a function called `prepare_data()` inside the `mtl_patients.py` module. This preparation consists of the following transformations taken from the paper and the author's code reference implementation:
# 1. Calculation of the mortality flag (prediction label) and mortality time for every patient in the dataset using an *extended* definition of mortality: death, a note of "Do Not Resuscitate" (DNR), or a note of "Comfort Measures Only" (CMO). In case any of these conditions are met for a patient, the corresponding mortality label is set to *True* and the corresponding mortality time is considered as the earliest time of any of the three conditions. After reviewing in detail the author's code implementation it seems mortality is based on deathtime and a CMO note but not DNR. However, the calculation of the time of death is based on the earliest time of the three conditions.
# 2. Data used for the prediction is only limited to the first certain amount of hours after a patient goes into the ICU. This amount of hours is called inside the code "a cutoff period" (observation window) and defines the period of data used to train all models. In addition, there is another number of hours called inside the code "the gap period" which represents the time between the end of the observation window and the beginning of the prediction window to prevent label leakage. All patients that died under the *extended* definition before the cutoff period plus the gap period or stayed less than the cutoff period are excluded from the experiment as part of this step. Also, all patients under the age of 15 are excluded (this is already part of the exclusion criteria of the MIMIC-Extract pipeline).
# 3. There are 29 vitals/labs timeseries selected by the paper. Only data within the cutoff period for vitals/labs is kept and rest is removed. This will be used for the rest of the machine learning pipeline.
# 4. All vitals/labs values are converted to z-scores so they all have zero mean and unit standard deviation. Those z-scores are rounded to the closest integer and clipped between $-4$ and $4$ or set to $9$ in case of `NaN`. This allows to map every vital/lab measurement (a float) to one of ten possible values $[-4, -3, -2, -1, 0, 1, 2, 3, 4, 9]$, so they can be converted to dummy values. After dummifying the vitals/labs, column for the $9$ values (`NaN`) is removed, and the resulting matrix is sparse and containing either $0$s or $1$s.
# 5. Every patient is padded with rows of zeroes for those hours that are missed. For example, if a patient only has vitals/labs for the first ten hours and the cutoff period is 24, code adds fourteen hours (rows) with zeroes for that patient. In the end, the matrix will have a size of $P \times T \times F$ as expected by the subsequent models.
# 6. Finally, static data (gender, age, and ethnicity) is converted to integers representing categories and dummified. In case of age, there are four buckets established; $(10, 30), (30, 50), (50, 70), (70, \infty)$; while ethnicity is broken into five buckets (asian, white, hispanic, black, other).
# 7. Cohort assignments based on first careunit or Simplified Acute Physiology Score (SAPS) II score quartile is calculated for each patient and returned as well.

# %% [markdown]
# ![Figure 1](../img/paper-181-fig-1.png)

# %% [markdown]
# The `discover_cohorts()` function inside the `mtl_patients.py` module is the one implementing the pipeline shown in the figure above and then calling the `prepare_data()` function detailed previously as the first step. Once data has been processed, the function will break the data in training, validation, and test data sets in a $70\%/10\%/20\%$ proportion.
#
# The training data is used to train an LSTM autoencoder. The main purpose of the LSTM autoencoder is to generate a fixed-length dense representation (embedding) of the sparse inputs trying to retain the most important parts of the inputs. The paper selected embeddings of size $50$ as the optimal dimension (hyperparameter). The purple box in the middle of the diagram above (a 2D matrix) represents the embeddings after the LSTM autoencoder learned the representation of the original 3D matrix of shape $(32537 \times 24 \times 232)$ where every row corresponds to a patient.
#
# Once the embeddings are calculated, a Gaussian Mixture Model is applied using $3$ clusters (the value the authors considered optimal). The result are the three green boxes representing three cohorts discovered in an unsupervised way and grouping similar patients based on the three static and the 29 time-varying vitals/labs selected from the MIMIC-III database.

# %% [markdown]
# ### 2.1. Cohort statistics at 24 hours and 48 hours

# %% [markdown]
# The paper runs two experiments. The first experiment uses a cutoff period of 24 hours, a gap period of 12 hours, and three clusters. Let's run this first experiment using the `discover_cohorts()` function and determine the corresponding cohort assignment for every patient that does not meet the exception criteria:

# %%
from mtl_patients import discover_cohorts

# %%
# %%time
cohort_unsupervised_24 = discover_cohorts(cutoff_hours=24, gap_hours=12, cohort_unsupervised_filename='../data/unsupervised_clusters_24.npy')
# Out:
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Preparing the data
# --------------------------------------------------------------------------------
#     Loading data from MIMIC-Extract pipeline...
#     Adding SAPS II score to static dataset...
#     Adding mortality columns to static dataset...
#     Discretizing X...
#         X.shape: (2200954, 33), X.subject_id.nunique(): 34472
#         X_discrete.shape: (2200954, 225), X_discrete.subject_id.nunique(): 34472
#     Keep only X_discrete[X_discrete.hours_in < 24]...
#         New X_discrete.shape: (808539, 223), new X_discrete.subject_id.nunique(): 34472
#     Padding patients with less than 24 hours of data...
#     Merging dataframes to create X_full...
#     Mortality per careunit...
#         MICU: 1138 out of 11403
#         SICU: 409 out of 5187
#         CCU: 344 out of 4907
#         CSRU: 139 out of 6971
#         TSICU: 291 out of 4245
#     Final shape of X: (32713, 24, 232)
#     Number of positive samples: 2321
#     Done!
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Discovering cohorts in an unsupervised way
# --------------------------------------------------------------------------------
#     Splitting data into train/validation/test sets...
# 2023-04-06 15:45:53.964599: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
#     Training LSTM autoencoder started at 06/04/2023 15:45:54. This will take several minutes (5 to 25). Please be patient...
# Epoch 1/100
# 179/179 [==============================] - 36s 189ms/step - loss: 0.0400 - val_loss: 0.0343
# Epoch 2/100
# 179/179 [==============================] - 33s 186ms/step - loss: 0.0322 - val_loss: 0.0302
# Epoch 3/100
# 179/179 [==============================] - 33s 187ms/step - loss: 0.0290 - val_loss: 0.0280
# Epoch 4/100
# 179/179 [==============================] - 34s 188ms/step - loss: 0.0274 - val_loss: 0.0268
# Epoch 5/100
# 179/179 [==============================] - 34s 188ms/step - loss: 0.0264 - val_loss: 0.0260
# Epoch 6/100
# 179/179 [==============================] - 34s 188ms/step - loss: 0.0258 - val_loss: 0.0255
# Epoch 7/100
# 179/179 [==============================] - 34s 188ms/step - loss: 0.0253 - val_loss: 0.0251
# Epoch 8/100
# 179/179 [==============================] - 33s 187ms/step - loss: 0.0249 - val_loss: 0.0247
# Epoch 9/100
# 179/179 [==============================] - 33s 187ms/step - loss: 0.0246 - val_loss: 0.0245
# Epoch 10/100
# 179/179 [==============================] - 33s 187ms/step - loss: 0.0244 - val_loss: 0.0243
# Epoch 11/100
# 179/179 [==============================] - 33s 187ms/step - loss: 0.0242 - val_loss: 0.0241
# Epoch 12/100
# 179/179 [==============================] - 34s 188ms/step - loss: 0.0241 - val_loss: 0.0240
# Epoch 13/100
# 179/179 [==============================] - 34s 187ms/step - loss: 0.0239 - val_loss: 0.0239
# Epoch 14/100
# 179/179 [==============================] - 33s 187ms/step - loss: 0.0238 - val_loss: 0.0238
# Epoch 15/100
# 179/179 [==============================] - 33s 187ms/step - loss: 0.0238 - val_loss: 0.0237
# Epoch 16/100
# 179/179 [==============================] - 33s 187ms/step - loss: 0.0237 - val_loss: 0.0236
# Epoch 17/100
# 179/179 [==============================] - 33s 187ms/step - loss: 0.0236 - val_loss: 0.0235
# Epoch 18/100
# 179/179 [==============================] - 33s 187ms/step - loss: 0.0235 - val_loss: 0.0235
# Epoch 19/100
# 179/179 [==============================] - 33s 187ms/step - loss: 0.0234 - val_loss: 0.0234
# Epoch 20/100
# 179/179 [==============================] - 33s 187ms/step - loss: 0.0234 - val_loss: 0.0233
# Epoch 21/100
# 179/179 [==============================] - 33s 187ms/step - loss: 0.0233 - val_loss: 0.0233
# Epoch 22/100
# 179/179 [==============================] - 33s 187ms/step - loss: 0.0232 - val_loss: 0.0232
# Epoch 23/100
# 179/179 [==============================] - 33s 187ms/step - loss: 0.0232 - val_loss: 0.0231
# Epoch 24/100
# 179/179 [==============================] - 33s 187ms/step - loss: 0.0231 - val_loss: 0.0231
# Epoch 25/100
# 179/179 [==============================] - 34s 187ms/step - loss: 0.0230 - val_loss: 0.0230
# Epoch 26/100
# 179/179 [==============================] - 34s 187ms/step - loss: 0.0230 - val_loss: 0.0230
# Epoch 27/100
# 179/179 [==============================] - 34s 187ms/step - loss: 0.0229 - val_loss: 0.0229
# Epoch 28/100
# 179/179 [==============================] - 34s 187ms/step - loss: 0.0229 - val_loss: 0.0228
# Epoch 29/100
# 179/179 [==============================] - 34s 187ms/step - loss: 0.0228 - val_loss: 0.0228
# Epoch 30/100
# 179/179 [==============================] - 34s 187ms/step - loss: 0.0227 - val_loss: 0.0227
# Epoch 31/100
# 179/179 [==============================] - 33s 187ms/step - loss: 0.0227 - val_loss: 0.0227
# Epoch 32/100
# 179/179 [==============================] - 34s 188ms/step - loss: 0.0226 - val_loss: 0.0226
# Epoch 33/100
# 179/179 [==============================] - 34s 188ms/step - loss: 0.0226 - val_loss: 0.0226
# Epoch 34/100
# 179/179 [==============================] - 34s 187ms/step - loss: 0.0225 - val_loss: 0.0225
# Epoch 35/100
# 179/179 [==============================] - 34s 188ms/step - loss: 0.0225 - val_loss: 0.0225
# Epoch 36/100
# 179/179 [==============================] - 34s 188ms/step - loss: 0.0225 - val_loss: 0.0224
# Epoch 37/100
# 179/179 [==============================] - 34s 188ms/step - loss: 0.0224 - val_loss: 0.0224
# Epoch 38/100
# 179/179 [==============================] - 34s 188ms/step - loss: 0.0224 - val_loss: 0.0224
# Epoch 39/100
# 179/179 [==============================] - 34s 188ms/step - loss: 0.0223 - val_loss: 0.0223
# Epoch 40/100
# 179/179 [==============================] - 34s 188ms/step - loss: 0.0223 - val_loss: 0.0223
# Epoch 41/100
# 179/179 [==============================] - 34s 188ms/step - loss: 0.0223 - val_loss: 0.0222
# Epoch 42/100
# 179/179 [==============================] - 34s 188ms/step - loss: 0.0222 - val_loss: 0.0222
# Epoch 43/100
# 179/179 [==============================] - 34s 188ms/step - loss: 0.0222 - val_loss: 0.0222
# Epoch 44/100
# 179/179 [==============================] - 34s 188ms/step - loss: 0.0221 - val_loss: 0.0221
# Epoch 45/100
# 179/179 [==============================] - 34s 188ms/step - loss: 0.0221 - val_loss: 0.0221
# Epoch 46/100
# 179/179 [==============================] - 34s 188ms/step - loss: 0.0221 - val_loss: 0.0221
# Epoch 47/100
# 179/179 [==============================] - 34s 188ms/step - loss: 0.0221 - val_loss: 0.0221
# Epoch 48/100
# 179/179 [==============================] - 34s 188ms/step - loss: 0.0220 - val_loss: 0.0220
# Epoch 49/100
# 179/179 [==============================] - 34s 188ms/step - loss: 0.0220 - val_loss: 0.0220
# Epoch 50/100
# 179/179 [==============================] - 34s 188ms/step - loss: 0.0220 - val_loss: 0.0220
# Epoch 51/100
# 179/179 [==============================] - 34s 188ms/step - loss: 0.0219 - val_loss: 0.0219
# Epoch 52/100
# 179/179 [==============================] - 34s 188ms/step - loss: 0.0219 - val_loss: 0.0219
# Epoch 53/100
# 179/179 [==============================] - 34s 188ms/step - loss: 0.0219 - val_loss: 0.0219
# Epoch 54/100
# 179/179 [==============================] - 34s 189ms/step - loss: 0.0219 - val_loss: 0.0219
# Epoch 55/100
# 179/179 [==============================] - 34s 189ms/step - loss: 0.0218 - val_loss: 0.0218
# Epoch 56/100
# 179/179 [==============================] - 34s 189ms/step - loss: 0.0218 - val_loss: 0.0218
# Epoch 57/100
# 179/179 [==============================] - 34s 188ms/step - loss: 0.0218 - val_loss: 0.0218
# Epoch 58/100
# 179/179 [==============================] - 34s 188ms/step - loss: 0.0218 - val_loss: 0.0218
# Epoch 59/100
# 179/179 [==============================] - 34s 188ms/step - loss: 0.0217 - val_loss: 0.0218
# Epoch 60/100
# 179/179 [==============================] - 34s 188ms/step - loss: 0.0217 - val_loss: 0.0217
# Epoch 61/100
# 179/179 [==============================] - 34s 188ms/step - loss: 0.0217 - val_loss: 0.0217
# Epoch 62/100
# 179/179 [==============================] - 34s 188ms/step - loss: 0.0217 - val_loss: 0.0217
# Epoch 63/100
# 179/179 [==============================] - 34s 188ms/step - loss: 0.0217 - val_loss: 0.0217
# Epoch 64/100
# 179/179 [==============================] - 34s 188ms/step - loss: 0.0216 - val_loss: 0.0216
# Epoch 65/100
# 179/179 [==============================] - 34s 188ms/step - loss: 0.0216 - val_loss: 0.0216
# Epoch 66/100
# 179/179 [==============================] - 34s 188ms/step - loss: 0.0216 - val_loss: 0.0216
# Epoch 67/100
# 179/179 [==============================] - 34s 188ms/step - loss: 0.0216 - val_loss: 0.0216
# Epoch 68/100
# 179/179 [==============================] - 34s 188ms/step - loss: 0.0215 - val_loss: 0.0216
# Epoch 69/100
# 179/179 [==============================] - 34s 188ms/step - loss: 0.0215 - val_loss: 0.0215
# Epoch 70/100
# 179/179 [==============================] - 34s 188ms/step - loss: 0.0215 - val_loss: 0.0215
# Epoch 71/100
# 179/179 [==============================] - 34s 188ms/step - loss: 0.0215 - val_loss: 0.0215
# Epoch 72/100
# 179/179 [==============================] - 34s 188ms/step - loss: 0.0215 - val_loss: 0.0215
# Epoch 73/100
# 179/179 [==============================] - 34s 188ms/step - loss: 0.0215 - val_loss: 0.0215
# Epoch 74/100
# 179/179 [==============================] - 34s 188ms/step - loss: 0.0214 - val_loss: 0.0215
# Epoch 75/100
# 179/179 [==============================] - 34s 188ms/step - loss: 0.0214 - val_loss: 0.0214
# Epoch 76/100
# 179/179 [==============================] - 34s 188ms/step - loss: 0.0214 - val_loss: 0.0214
# Epoch 77/100
# 179/179 [==============================] - 34s 188ms/step - loss: 0.0214 - val_loss: 0.0214
# Epoch 78/100
# 179/179 [==============================] - 34s 188ms/step - loss: 0.0214 - val_loss: 0.0214
# Epoch 79/100
# 179/179 [==============================] - 34s 188ms/step - loss: 0.0214 - val_loss: 0.0214
# Epoch 80/100
# 179/179 [==============================] - 34s 188ms/step - loss: 0.0213 - val_loss: 0.0214
# Epoch 81/100
# 179/179 [==============================] - 34s 188ms/step - loss: 0.0213 - val_loss: 0.0214
# Epoch 82/100
# 179/179 [==============================] - 33s 187ms/step - loss: 0.0213 - val_loss: 0.0213
# Epoch 83/100
# 179/179 [==============================] - 33s 187ms/step - loss: 0.0213 - val_loss: 0.0213
# Epoch 84/100
# 179/179 [==============================] - 33s 187ms/step - loss: 0.0213 - val_loss: 0.0213
# Epoch 85/100
# 179/179 [==============================] - 33s 186ms/step - loss: 0.0213 - val_loss: 0.0213
# Epoch 86/100
# 179/179 [==============================] - 33s 186ms/step - loss: 0.0212 - val_loss: 0.0213
# Epoch 87/100
# 179/179 [==============================] - 33s 186ms/step - loss: 0.0212 - val_loss: 0.0213
# Epoch 88/100
# 179/179 [==============================] - 33s 186ms/step - loss: 0.0212 - val_loss: 0.0213
# Epoch 89/100
# 179/179 [==============================] - 33s 186ms/step - loss: 0.0212 - val_loss: 0.0212
# Epoch 90/100
# 179/179 [==============================] - 33s 186ms/step - loss: 0.0212 - val_loss: 0.0212
# Epoch 91/100
# 179/179 [==============================] - 33s 186ms/step - loss: 0.0212 - val_loss: 0.0212
# Epoch 92/100
# 179/179 [==============================] - 33s 186ms/step - loss: 0.0212 - val_loss: 0.0212
# Epoch 93/100
# 179/179 [==============================] - 33s 186ms/step - loss: 0.0211 - val_loss: 0.0212
# Epoch 94/100
# 179/179 [==============================] - 33s 185ms/step - loss: 0.0211 - val_loss: 0.0212
# Epoch 95/100
# 179/179 [==============================] - 33s 185ms/step - loss: 0.0211 - val_loss: 0.0212
# Epoch 96/100
# 179/179 [==============================] - 33s 185ms/step - loss: 0.0211 - val_loss: 0.0211
# Epoch 97/100
# 179/179 [==============================] - 33s 185ms/step - loss: 0.0211 - val_loss: 0.0211
# Epoch 98/100
# 179/179 [==============================] - 33s 185ms/step - loss: 0.0211 - val_loss: 0.0211
# Epoch 99/100
# 179/179 [==============================] - 33s 185ms/step - loss: 0.0211 - val_loss: 0.0211
# Epoch 100/100
# 179/179 [==============================] - 33s 184ms/step - loss: 0.0210 - val_loss: 0.0211
#     LSTM autoencoder trained!
# 716/716 [==============================] - 4s 4ms/step
# 1023/1023 [==============================] - 5s 4ms/step
# Patient embeddings created! Shape: (32713, 50)
#     Training Gaussian Mixture Model...
#     Gaussian Mixture Model applied to embeddings! Results shape: (32713,)
#     Cluster results saved to '../data/unsupervised_clusters_24.npy'
#     Done!
# CPU times: user 56min 25s, sys: 20.4 s, total: 56min 46s
# Wall time: 56min 27s

# %% [markdown]
# The second experiment uses a cutoff period of 48 hours, a gap period of 24 hours, and two instead of three clusters. The reduction in the number of clusters is proposed by the authors (Table 3 of the paper). Let's run now this second experiment using the `discover_cohorts()` function and determine the corresponding cohort assignment for every patient that does not meet the exception criteria:

# %%
# %%time
cohort_unsupervised_48 = discover_cohorts(cutoff_hours=48, gap_hours=24, num_clusters=2, cohort_unsupervised_filename='../data/unsupervised_clusters_48.npy')
# Out:
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Preparing the data
# --------------------------------------------------------------------------------
#     Loading data from MIMIC-Extract pipeline...
#     Adding SAPS II score to static dataset...
#     Adding mortality columns to static dataset...
#     Discretizing X...
#         X.shape: (2200954, 33), X.subject_id.nunique(): 34472
#         X_discrete.shape: (2200954, 225), X_discrete.subject_id.nunique(): 34472
#     Keep only X_discrete[X_discrete.hours_in < 48]...
#         New X_discrete.shape: (1349653, 223), new X_discrete.subject_id.nunique(): 34472
#     Padding patients with less than 48 hours of data...
#     Merging dataframes to create X_full...
#     Mortality per careunit...
#         MICU: 866 out of 10409
#         SICU: 303 out of 4815
#         CCU: 258 out of 4403
#         CSRU: 110 out of 6865
#         TSICU: 202 out of 3950
#     Final shape of X: (30442, 48, 232)
#     Number of positive samples: 1739
#     Done!
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Discovering cohorts in an unsupervised way
# --------------------------------------------------------------------------------
#     Splitting data into train/validation/test sets...
#     Training LSTM autoencoder started at 06/04/2023 16:42:34. This will take several minutes (5 to 25). Please be patient...
# Epoch 1/100
# 167/167 [==============================] - 64s 371ms/step - loss: 0.0345 - val_loss: 0.0295
# Epoch 2/100
# 167/167 [==============================] - 61s 366ms/step - loss: 0.0273 - val_loss: 0.0259
# Epoch 3/100
# 167/167 [==============================] - 61s 366ms/step - loss: 0.0247 - val_loss: 0.0241
# Epoch 4/100
# 167/167 [==============================] - 61s 366ms/step - loss: 0.0234 - val_loss: 0.0232
# Epoch 5/100
# 167/167 [==============================] - 61s 366ms/step - loss: 0.0227 - val_loss: 0.0226
# Epoch 6/100
# 167/167 [==============================] - 61s 366ms/step - loss: 0.0222 - val_loss: 0.0222
# Epoch 7/100
# 167/167 [==============================] - 61s 366ms/step - loss: 0.0218 - val_loss: 0.0219
# Epoch 8/100
# 167/167 [==============================] - 61s 366ms/step - loss: 0.0216 - val_loss: 0.0217
# Epoch 9/100
# 167/167 [==============================] - 61s 366ms/step - loss: 0.0213 - val_loss: 0.0215
# Epoch 10/100
# 167/167 [==============================] - 61s 367ms/step - loss: 0.0212 - val_loss: 0.0213
# Epoch 11/100
# 167/167 [==============================] - 61s 366ms/step - loss: 0.0210 - val_loss: 0.0212
# Epoch 12/100
# 167/167 [==============================] - 61s 366ms/step - loss: 0.0209 - val_loss: 0.0210
# Epoch 13/100
# 167/167 [==============================] - 61s 366ms/step - loss: 0.0207 - val_loss: 0.0209
# Epoch 14/100
# 167/167 [==============================] - 61s 366ms/step - loss: 0.0206 - val_loss: 0.0208
# Epoch 15/100
# 167/167 [==============================] - 61s 366ms/step - loss: 0.0205 - val_loss: 0.0207
# Epoch 16/100
# 167/167 [==============================] - 61s 366ms/step - loss: 0.0205 - val_loss: 0.0207
# Epoch 17/100
# 167/167 [==============================] - 61s 366ms/step - loss: 0.0204 - val_loss: 0.0206
# Epoch 18/100
# 167/167 [==============================] - 61s 366ms/step - loss: 0.0203 - val_loss: 0.0205
# Epoch 19/100
# 167/167 [==============================] - 61s 366ms/step - loss: 0.0202 - val_loss: 0.0205
# Epoch 20/100
# 167/167 [==============================] - 61s 366ms/step - loss: 0.0202 - val_loss: 0.0204
# Epoch 21/100
# 167/167 [==============================] - 61s 366ms/step - loss: 0.0201 - val_loss: 0.0204
# Epoch 22/100
# 167/167 [==============================] - 61s 366ms/step - loss: 0.0201 - val_loss: 0.0203
# Epoch 23/100
# 167/167 [==============================] - 61s 366ms/step - loss: 0.0200 - val_loss: 0.0203
# Epoch 24/100
# 167/167 [==============================] - 61s 366ms/step - loss: 0.0200 - val_loss: 0.0202
# Epoch 25/100
# 167/167 [==============================] - 61s 366ms/step - loss: 0.0199 - val_loss: 0.0202
# Epoch 26/100
# 167/167 [==============================] - 61s 366ms/step - loss: 0.0199 - val_loss: 0.0201
# Epoch 27/100
# 167/167 [==============================] - 61s 366ms/step - loss: 0.0198 - val_loss: 0.0201
# Epoch 28/100
# 167/167 [==============================] - 61s 366ms/step - loss: 0.0198 - val_loss: 0.0200
# Epoch 29/100
# 167/167 [==============================] - 61s 366ms/step - loss: 0.0198 - val_loss: 0.0200
# Epoch 30/100
# 167/167 [==============================] - 61s 366ms/step - loss: 0.0197 - val_loss: 0.0200
# Epoch 31/100
# 167/167 [==============================] - 61s 366ms/step - loss: 0.0197 - val_loss: 0.0199
# Epoch 32/100
# 167/167 [==============================] - 61s 366ms/step - loss: 0.0196 - val_loss: 0.0199
# Epoch 33/100
# 167/167 [==============================] - 61s 367ms/step - loss: 0.0196 - val_loss: 0.0198
# Epoch 34/100
# 167/167 [==============================] - 61s 366ms/step - loss: 0.0196 - val_loss: 0.0198
# Epoch 35/100
# 167/167 [==============================] - 61s 366ms/step - loss: 0.0195 - val_loss: 0.0198
# Epoch 36/100
# 167/167 [==============================] - 61s 366ms/step - loss: 0.0195 - val_loss: 0.0197
# Epoch 37/100
# 167/167 [==============================] - 62s 369ms/step - loss: 0.0195 - val_loss: 0.0197
# Epoch 38/100
# 167/167 [==============================] - 62s 371ms/step - loss: 0.0194 - val_loss: 0.0197
# Epoch 39/100
# 167/167 [==============================] - 62s 372ms/step - loss: 0.0194 - val_loss: 0.0196
# Epoch 40/100
# 167/167 [==============================] - 62s 372ms/step - loss: 0.0194 - val_loss: 0.0196
# Epoch 41/100
# 167/167 [==============================] - 62s 368ms/step - loss: 0.0193 - val_loss: 0.0196
# Epoch 42/100
# 167/167 [==============================] - 62s 373ms/step - loss: 0.0193 - val_loss: 0.0195
# Epoch 43/100
# 167/167 [==============================] - 62s 369ms/step - loss: 0.0193 - val_loss: 0.0195
# Epoch 44/100
# 167/167 [==============================] - 61s 368ms/step - loss: 0.0192 - val_loss: 0.0195
# Epoch 45/100
# 167/167 [==============================] - 62s 369ms/step - loss: 0.0192 - val_loss: 0.0195
# Epoch 46/100
# 167/167 [==============================] - 61s 368ms/step - loss: 0.0192 - val_loss: 0.0194
# Epoch 47/100
# 167/167 [==============================] - 61s 367ms/step - loss: 0.0192 - val_loss: 0.0194
# Epoch 48/100
# 167/167 [==============================] - 62s 369ms/step - loss: 0.0191 - val_loss: 0.0194
# Epoch 49/100
# 167/167 [==============================] - 62s 370ms/step - loss: 0.0191 - val_loss: 0.0194
# Epoch 50/100
# 167/167 [==============================] - 61s 367ms/step - loss: 0.0191 - val_loss: 0.0193
# Epoch 51/100
# 167/167 [==============================] - 61s 368ms/step - loss: 0.0191 - val_loss: 0.0193
# Epoch 52/100
# 167/167 [==============================] - 61s 366ms/step - loss: 0.0190 - val_loss: 0.0193
# Epoch 53/100
# 167/167 [==============================] - 61s 366ms/step - loss: 0.0190 - val_loss: 0.0193
# Epoch 54/100
# 167/167 [==============================] - 61s 366ms/step - loss: 0.0190 - val_loss: 0.0193
# Epoch 55/100
# 167/167 [==============================] - 61s 366ms/step - loss: 0.0190 - val_loss: 0.0192
# Epoch 56/100
# 167/167 [==============================] - 61s 366ms/step - loss: 0.0190 - val_loss: 0.0192
# Epoch 57/100
# 167/167 [==============================] - 61s 366ms/step - loss: 0.0189 - val_loss: 0.0192
# Epoch 58/100
# 167/167 [==============================] - 61s 366ms/step - loss: 0.0189 - val_loss: 0.0192
# Epoch 59/100
# 167/167 [==============================] - 61s 366ms/step - loss: 0.0189 - val_loss: 0.0192
# Epoch 60/100
# 167/167 [==============================] - 61s 366ms/step - loss: 0.0189 - val_loss: 0.0192
# Epoch 61/100
# 167/167 [==============================] - 61s 366ms/step - loss: 0.0189 - val_loss: 0.0191
# Epoch 62/100
# 167/167 [==============================] - 61s 366ms/step - loss: 0.0188 - val_loss: 0.0191
# Epoch 63/100
# 167/167 [==============================] - 62s 370ms/step - loss: 0.0188 - val_loss: 0.0191
# Epoch 64/100
# 167/167 [==============================] - 61s 368ms/step - loss: 0.0188 - val_loss: 0.0191
# Epoch 65/100
# 167/167 [==============================] - 62s 368ms/step - loss: 0.0188 - val_loss: 0.0191
# Epoch 66/100
# 167/167 [==============================] - 62s 369ms/step - loss: 0.0188 - val_loss: 0.0191
# Epoch 67/100
# 167/167 [==============================] - 62s 369ms/step - loss: 0.0188 - val_loss: 0.0190
# Epoch 68/100
# 167/167 [==============================] - 62s 369ms/step - loss: 0.0188 - val_loss: 0.0190
# Epoch 69/100
# 167/167 [==============================] - 62s 371ms/step - loss: 0.0187 - val_loss: 0.0190
# Epoch 70/100
# 167/167 [==============================] - 61s 368ms/step - loss: 0.0187 - val_loss: 0.0190
# Epoch 71/100
# 167/167 [==============================] - 61s 368ms/step - loss: 0.0187 - val_loss: 0.0190
# Epoch 72/100
# 167/167 [==============================] - 61s 368ms/step - loss: 0.0187 - val_loss: 0.0190
# Epoch 73/100
# 167/167 [==============================] - 62s 369ms/step - loss: 0.0187 - val_loss: 0.0189
# Epoch 74/100
# 167/167 [==============================] - 61s 368ms/step - loss: 0.0187 - val_loss: 0.0189
# Epoch 75/100
# 167/167 [==============================] - 62s 368ms/step - loss: 0.0187 - val_loss: 0.0189
# Epoch 76/100
# 167/167 [==============================] - 62s 368ms/step - loss: 0.0186 - val_loss: 0.0189
# Epoch 77/100
# 167/167 [==============================] - 61s 368ms/step - loss: 0.0186 - val_loss: 0.0189
# Epoch 78/100
# 167/167 [==============================] - 62s 369ms/step - loss: 0.0186 - val_loss: 0.0189
# Epoch 79/100
# 167/167 [==============================] - 62s 369ms/step - loss: 0.0186 - val_loss: 0.0189
# Epoch 80/100
# 167/167 [==============================] - 61s 368ms/step - loss: 0.0186 - val_loss: 0.0189
# Epoch 81/100
# 167/167 [==============================] - 61s 368ms/step - loss: 0.0186 - val_loss: 0.0189
# Epoch 82/100
# 167/167 [==============================] - 62s 369ms/step - loss: 0.0186 - val_loss: 0.0188
# Epoch 83/100
# 167/167 [==============================] - 62s 368ms/step - loss: 0.0186 - val_loss: 0.0188
# Epoch 84/100
# 167/167 [==============================] - 62s 369ms/step - loss: 0.0185 - val_loss: 0.0188
# Epoch 85/100
# 167/167 [==============================] - 62s 369ms/step - loss: 0.0185 - val_loss: 0.0188
# Epoch 86/100
# 167/167 [==============================] - 62s 370ms/step - loss: 0.0185 - val_loss: 0.0188
# Epoch 87/100
# 167/167 [==============================] - 62s 369ms/step - loss: 0.0185 - val_loss: 0.0188
# Epoch 88/100
# 167/167 [==============================] - 62s 370ms/step - loss: 0.0185 - val_loss: 0.0188
# Epoch 89/100
# 167/167 [==============================] - 62s 369ms/step - loss: 0.0185 - val_loss: 0.0188
# Epoch 90/100
# 167/167 [==============================] - 62s 369ms/step - loss: 0.0185 - val_loss: 0.0188
# Epoch 91/100
# 167/167 [==============================] - 62s 369ms/step - loss: 0.0185 - val_loss: 0.0187
# Epoch 92/100
# 167/167 [==============================] - 62s 370ms/step - loss: 0.0185 - val_loss: 0.0187
# Epoch 93/100
# 167/167 [==============================] - 62s 371ms/step - loss: 0.0185 - val_loss: 0.0187
# Epoch 94/100
# 167/167 [==============================] - 62s 369ms/step - loss: 0.0184 - val_loss: 0.0187
# Epoch 95/100
# 167/167 [==============================] - 61s 367ms/step - loss: 0.0184 - val_loss: 0.0187
# Epoch 96/100
# 167/167 [==============================] - 61s 368ms/step - loss: 0.0184 - val_loss: 0.0187
# Epoch 97/100
# 167/167 [==============================] - 61s 368ms/step - loss: 0.0184 - val_loss: 0.0187
# Epoch 98/100
# 167/167 [==============================] - 61s 368ms/step - loss: 0.0184 - val_loss: 0.0187
# Epoch 99/100
# 167/167 [==============================] - 61s 367ms/step - loss: 0.0184 - val_loss: 0.0187
# Epoch 100/100
# 167/167 [==============================] - 62s 368ms/step - loss: 0.0184 - val_loss: 0.0187
#     LSTM autoencoder trained!
# 666/666 [==============================] - 6s 8ms/step
# 952/952 [==============================] - 9s 8ms/step
# Patient embeddings created! Shape: (30442, 50)
#     Training Gaussian Mixture Model...
#     Gaussian Mixture Model applied to embeddings! Results shape: (30442,)
#     Cluster results saved to '../data/unsupervised_clusters_48.npy'
#     Done!
# CPU times: user 1h 43min 6s, sys: 29.9 s, total: 1h 43min 36s
# Wall time: 1h 43min 15s

# %% [markdown]
# Let's summarize the results of the 24 hour and 48 hour experiments similar to what Table 3 of the paper shows.

# %%
#----------------------------------------------------
# Let's create the summary for the 24 hour experiment

cohort_unsupervised_24 = np.load('../data/unsupervised_clusters_24.npy')

from mtl_patients import prepare_data
_, Y, _, _, subject_ids = prepare_data(cutoff_hours=24, gap_hours=12)
# Out:
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Preparing the data
# --------------------------------------------------------------------------------
#     Loading data from MIMIC-Extract pipeline...
#     Adding SAPS II score to static dataset...
#     Adding mortality columns to static dataset...
#     Discretizing X...
#         X.shape: (2200954, 33), X.subject_id.nunique(): 34472
#         X_discrete.shape: (2200954, 225), X_discrete.subject_id.nunique(): 34472
#     Keep only X_discrete[X_discrete.hours_in < 24]...
#         New X_discrete.shape: (808539, 223), new X_discrete.subject_id.nunique(): 34472
#     Padding patients with less than 24 hours of data...
#     Merging dataframes to create X_full...
#     Mortality per careunit...
#         MICU: 1138 out of 11403
#         SICU: 409 out of 5187
#         CCU: 344 out of 4907
#         CSRU: 139 out of 6971
#         TSICU: 291 out of 4245
#     Final shape of X: (32713, 24, 232)
#     Number of positive samples: 2321
#     Done!

# %%
subject_ids = np.array(subject_ids.tolist())
cohort_unsupervised_24_df = pd.DataFrame({'subject_id': subject_ids, 'Y': Y, 'Group': cohort_unsupervised_24}, dtype=int)

# calculate summaries per cohort (24 hours)
table3_a_df = cohort_unsupervised_24_df.groupby('Group').agg(
    N=('Y', 'size'),
    n=('Y', 'sum'),
)
table3_a_df.loc[:, 'Experiment'] = '24 hours'
table3_a_df.loc[:, 'Cohort Type'] = 'Unsupervised'

# calculate overall summary (24 hours)
table3_a_overall_df = table3_a_df.groupby(['*'] * len(table3_a_df)).agg(
    N=('N', 'sum'),
    n=('n', 'sum'),
)
table3_a_overall_df.index.name = 'Group'
table3_a_overall_df.loc[:, 'Experiment'] = '24 hours'
table3_a_overall_df.loc[:, 'Cohort Type'] = 'Global'

# merge 24 hour tables and make cosmetic changes
table3_a_df = pd.concat([table3_a_df, table3_a_overall_df], axis=0)
table3_a_df.reset_index(inplace=True)
table3_a_df.set_index(['Experiment', 'Cohort Type', 'Group'], inplace=True)

# %%
#----------------------------------------------------
# Let's create the summary for the 48 hour experiment

cohort_unsupervised_48 = np.load('../data/unsupervised_clusters_48.npy')

_, Y, _, _, subject_ids = prepare_data(cutoff_hours=48, gap_hours=24)
# Out:
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Preparing the data
# --------------------------------------------------------------------------------
#     Loading data from MIMIC-Extract pipeline...
#     Adding SAPS II score to static dataset...
#     Adding mortality columns to static dataset...
#     Discretizing X...
#         X.shape: (2200954, 33), X.subject_id.nunique(): 34472
#         X_discrete.shape: (2200954, 225), X_discrete.subject_id.nunique(): 34472
#     Keep only X_discrete[X_discrete.hours_in < 48]...
#         New X_discrete.shape: (1349653, 223), new X_discrete.subject_id.nunique(): 34472
#     Padding patients with less than 48 hours of data...
#     Merging dataframes to create X_full...
#     Mortality per careunit...
#         MICU: 866 out of 10409
#         SICU: 303 out of 4815
#         CCU: 258 out of 4403
#         CSRU: 110 out of 6865
#         TSICU: 202 out of 3950
#     Final shape of X: (30442, 48, 232)
#     Number of positive samples: 1739
#     Done!

# %%
subject_ids = np.array(subject_ids.tolist())
cohort_unsupervised_48_df = pd.DataFrame({'subject_id': subject_ids, 'Y': Y, 'Group': cohort_unsupervised_48}, dtype=int)

# calculate summaries per cohort (48 hours)
table3_b_df = cohort_unsupervised_48_df.groupby('Group').agg(
    N=('Y', 'size'),
    n=('Y', 'sum'),
)
table3_b_df.loc[:, 'Experiment'] = '48 hours'
table3_b_df.loc[:, 'Cohort Type'] = 'Unsupervised'

# calculate overall summary (48 hours)
table3_b_overall_df = table3_b_df.groupby(['*'] * len(table3_b_df)).agg(
    N=('N', 'sum'),
    n=('n', 'sum'),
)
table3_b_overall_df.index.name = 'Group'
table3_b_overall_df.loc[:, 'Experiment'] = '48 hours'
table3_b_overall_df.loc[:, 'Cohort Type'] = 'Global'

# merge 48 hour tables and make cosmetic changes
table3_b_df = pd.concat([table3_b_df, table3_b_overall_df], axis=0)
table3_b_df.reset_index(inplace=True)
table3_b_df.set_index(['Experiment', 'Cohort Type', 'Group'], inplace=True)

# %%
#--------------------------------------------------------------------
# Now let's merge results for 24 and 48 hour experiments in one table

# merge 24 hour and 48 hour tables
table3_df = pd.concat([table3_a_df, table3_b_df], axis=0)

# calculate class imbalance
table3_df.loc[:, 'Class Imbalance'] = table3_df.loc[:, 'n'] / table3_df.loc[:, 'N']
table3_df.loc[:, 'Class Imbalance'] = table3_df.loc[:, 'Class Imbalance'].round(4)

# %%
table3_df
# Out:
#                                    N     n  Class Imbalance
# Experiment Cohort Type  Group
# 24 hours   Unsupervised 0       4087   347           0.0849
#                         1      18593  1249           0.0672
#                         2      10033   725           0.0723
#            Global       *      32713  2321           0.0710
# 48 hours   Unsupervised 0      13092   574           0.0438
#                         1      17350  1165           0.0671
#            Global       *      30442  1739           0.0571

# %% [markdown]
# Table above is the equivalent to Table 3 in the paper. We can see the results are different. Data from MIMIC-Extract might be different from the data used by the authors.
#
# For the 24 hours experiment, size of the clusters are different and mortality as well. For instance, clusters 0 and 1 are smaller compared to cluster 2 but the mortality rate is significantly higher (9.27% and 10.15% versus 4.49%). For the 48 hours experiment, size and mortality of the two resulting clusters are closer when compared to the results from the 24 hour experiment.

# %% [markdown]
# ### 2.2. Visualization of selected lab test and vital signs features

# %% [markdown]
# In this section, we will try to reproduce the results from Figure 4 (section 6.1.1) in the paper. In Figure 4, data from experiment 1 (24 hours) is used to create heatmap plots to determine if patients from different cohorts are physiologically distinct. To do that, we added the function `get_heatmap_data()` to get the mean of all z-scores by patient, by hour in the ICU, by cohort.

# %% [markdown]
# #### 2.2.1. Heatmap plots for experiment 1 (24 hours)

# %% [markdown]
# Let's run the `get_heatmap_data()` function using the cohorts discovered in experiment 1 (24 hour cutoff period and 12 hour gap period):

# %%
# %%time

from mtl_patients import get_heatmap_data
import seaborn as sns
import matplotlib.pyplot as plt

labs_df, vitals_df = get_heatmap_data(cutoff_hours=24, gap_hours=12,
                                      cohort_unsupervised_filename='../data/unsupervised_clusters_24.npy')
# Out:
# CPU times: user 2.76 s, sys: 1.11 s, total: 3.86 s
# Wall time: 3.55 s

# %% [markdown]
# Let's plot the heatmaps for the selected lab tests and vitals:

# %%
num_cohorts = len(np.unique(labs_df.index.get_level_values(0)))
fig, axs = plt.subplots(nrows=2, ncols=num_cohorts)
fig.set_size_inches(24, 12)
for i in np.arange(num_cohorts):
    plot_df = labs_df.unstack(1).stack(1).query(f'cohort == {i}').droplevel(0)
    sns.heatmap(plot_df, ax=axs[0, i], yticklabels=True if i==0 else False).set(title=f'Lab Tests – Cohort {i}')
for i in np.arange(num_cohorts):
    plot_df = vitals_df.unstack(1).stack(1).query(f'cohort == {i}').droplevel(0)
    sns.heatmap(plot_df, ax=axs[1, i], yticklabels=True if i==0 else False).set(title=f'Vitals – Cohort {i}')
plt.savefig('../img/heatmap_24')

# %% [markdown]
# From the heatmap plots there are some trends in the physiological data that seems to show a distinction between cohorts. In case of labs glucose and blood area nitrogen seems to be different between the three cohorts. However, some of the vitals definitely show different trends in some cases. Blood pressure across the different cohorts is different. When cohort 0 patients have a diastolic blood pressure that tends to drop the longer the patient stays, patients from cohort 2 have a diastolic blood pressure that tends to increase.

# %% [markdown]
# #### 2.2.2. Heatmap plots for experiment 2 (48 hours)

# %% [markdown]
# Let's run the `get_heatmap_data()` function using the cohorts discovered in experiment 2 (48 hour cutoff period and 24 hour gap period):

# %%
# %%time
labs_df, vitals_df = get_heatmap_data(cutoff_hours=48, gap_hours=24,
                                      cohort_unsupervised_filename='../data/unsupervised_clusters_48.npy')
# Out:
# CPU times: user 2.97 s, sys: 1.19 s, total: 4.16 s
# Wall time: 3.79 s

# %% [markdown]
# Let's plot the heatmaps for the selected lab tests and vitals:

# %%
num_cohorts = len(np.unique(labs_df.index.get_level_values(0)))
fig, axs = plt.subplots(nrows=2, ncols=num_cohorts)
fig.set_size_inches(24, 12)
for i in np.arange(num_cohorts):
    plot_df = labs_df.unstack(1).stack(1).query(f'cohort == {i}').droplevel(0)
    sns.heatmap(plot_df, ax=axs[0, i], yticklabels=True if i==0 else False).set(title=f'Lab Tests – Cohort {i}')
for i in np.arange(num_cohorts):
    plot_df = vitals_df.unstack(1).stack(1).query(f'cohort == {i}').droplevel(0)
    sns.heatmap(plot_df, ax=axs[1, i], yticklabels=True if i==0 else False).set(title=f'Vitals – Cohort {i}')
plt.savefig('../img/heatmap_48')

# %% [markdown]
# In the 48 hour experiment, labs do not show significant differences between the two cohorts. However, the vitals show changes in the blood pressure where cohort 1 trend is more on the high side compared to cohort 0.

# %% [markdown]
# ## 3. Predicting In-Hospital Mortality

# %% [markdown]
# As mentioned in the previous section, the paper uses a two-step pipeline to: 1) identify relevant patient cohorts, and 2) use those relevant cohorts as separate tasks in a multi-lask learning framework to predict in-hospital mortality. In this section, we will focus on the second step of the pipeline, i.e., use multi-task learning to make in-hospital mortality predictions for different patient cohorts.

# %% [markdown]
# The second step uses as input the result from the first step which is a series of 3D matrices, one per discovered cohort, of shape $(P \times T \times F)$ where $P$ represents the number of patients, $T$ the number of timesteps, and $F$ the number of features. As an example, the 24 hour experiment described by the authors in the paper and reproduced in the previous section resulted in three cohorts (clusters) called group 0, group 1, and group 2 where the shapes of the corresponding 3D matrices are:
# * $14120 \times 24 \times 232$ for group 0,
# * $10841 \times 24 \times 232$ for group 1, and
# * $7752 \times 24 \times 232$ for group 2.

# %% [markdown]
# To convert these matrices into predictions, the paper proposes an LSTM for all model configurations including the baseline. In particular, the paper shows results from two specific models: a baseline model that is called *global* and using single-task learning and the multi-task learning model the authors claim as superior to the baseline.

# %% [markdown]
# A diagram of the baseline (*global*) model proposed by the authors is shown below. As it can be seen, this model consists of an LSTM layer of 16 cells using a RELU activation function followed by a *single* dense layer with a sigmoid activation function. The result of the dense (fully-connected) layer is an estimate of the probability of in-hospital mortality for a given patient. This baseline model is trained with all patient samples regardless the cohort, hence the name *global*, and used for per cohort predictions.

# %% [markdown]
# ![Figure 2](../img/paper-181-fig-2.png)

# %% [markdown]
# Moving to the second model and the one the authors claim it provides benefits against the baseline is the so called *multi-task learning model*. This model consists of an LSTM layer with same number of cells (16) as the baseline model, to ensure the comparison is fair, connected to as many dense layers as population subgroups (cohorts). Each of these cohorts is considered a *task* and authors propose training these models on multiple tasks simultaneously in contrast to the baseline model with just one dense layer. The benefit of this approach according to the authors is the ability to share knowledge learned from one task (cohort) to rest of tasks under the assumption that the subpopulations used are distinct enough with relation to the outcome learned (mortality) that such shared knowledge truly exists. A representation of the multi-task learning model is shown below:

# %% [markdown]
# ![Figure 3](../img/paper-181-fig-3.png)

# %% [markdown]
# For benchmarking purposes of the entire pipeline, the authors compared the results from running the pipeline using unsupervised cohort discovery (step one) against cohorts created using the first careunit the patient went into which can be considered an engineered feature. We will show those results in the next subsections.
#
# The overall performance of this model is measured using both macro and micro metrics (section 4.3 in the paper) where:
# * In *micro* metrics all predicted probabilities for all patients are treated as if they come from a single classifier: $\text{Metric}_\text{Micro} = \text{Metric}([\hat{y}_0, ..., \hat{y}_k], [y_0, ..., y_K])$.
# * In *macro* metrics probabilities are evaluated on a *per cohort* basis, and then averaged: $\text{Metric}_\text{Macro} = \dfrac{1}{K} \displaystyle\sum_{k=0}^K \text{Metric}(\hat{y}_K, y_K)$.
#
# Paper suggests that, although micro metrics are the ones typically chosen in the literature, evaluating performance on different subpopulations will benefit from macro metrics instead of micro metrics specially when there is class imbalance in every cohort. All results show macro and micro versions of the metrics for the aggregate performance of the models.
#
# All results being used for comparison between models by the paper will use three metrics:
# * AUC (Area Under the ROC Curve) for every cohort and, for the aggregate performance, macro and micro.
# * PPV (Positive Predictive Value which is same as Precision) for every cohort and, for the aggregate performance, macro and micro. This PPV is calculated at a sensitivity of 80%, a value selected by the paper authors.
# * Specificity for every cohort and, for the aggregate performance, macro and micro. This specificity is calculated at a sensitivity of 80%, a value selected by the paper authors.

# %% [markdown]
# All in-hospital mortality prediction tasks are implemented using the function `run_mortality_prediction_task()`. This function will call other functions to prepare the data, split the data in training/validation/test data sets, train the corresponding model, predict using the resulting model, and calculate the metrics of the model.

# %% [markdown]
# ### 3.1. In-Hospital Mortality Prediction – Baseline (*Global*) Model at 24 Hours

# %% [markdown]
# Let's first run the mortality prediction task using the *global* model (baseline) in the 24 hour experiment setting. In this experiment, the cutoff period is 24 hours and the gap period is 12 hours, meaning model can only feed from patient data collected during the first 24 hours of the ICU stay, and predict mortality 36 hours after patient goes into the ICU to avoid label leakage. In terms of the cohort type, let's go with careunits first:

# %%
# %%time

from mtl_patients import run_mortality_prediction_task

metrics_global_24_careunits_df = run_mortality_prediction_task(model_type='global', cutoff_hours=24, gap_hours=12, cohort_criteria_to_select='careunits')
# Out:
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Preparing the data
# --------------------------------------------------------------------------------
#     Loading data from MIMIC-Extract pipeline...
#     Adding SAPS II score to static dataset...
#     Adding mortality columns to static dataset...
#     Discretizing X...
#         X.shape: (2200954, 33), X.subject_id.nunique(): 34472
#         X_discrete.shape: (2200954, 225), X_discrete.subject_id.nunique(): 34472
#     Keep only X_discrete[X_discrete.hours_in < 24]...
#         New X_discrete.shape: (808539, 223), new X_discrete.subject_id.nunique(): 34472
#     Padding patients with less than 24 hours of data...
#     Merging dataframes to create X_full...
#     Mortality per careunit...
#         MICU: 1138 out of 11403
#         SICU: 409 out of 5187
#         CCU: 344 out of 4907
#         CSRU: 139 out of 6971
#         TSICU: 291 out of 4245
#     Final shape of X: (32713, 24, 232)
#     Number of positive samples: 2321
#     Done!
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Running the Mortality Prediction Task
# --------------------------------------------------------------------------------
#     Splitting data into train/validation/test sets...
#     Calculating number of training samples in cohort...
#         # of patients in cohort CCU is 3464
#         # of patients in cohort CSRU is 4848
#         # of patients in cohort MICU is 7912
#         # of patients in cohort SICU is 3696
#         # of patients in cohort TSICU is 2978
#     ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#     Training 'global' model...
# Model: "single_task_learning_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 16)                15936
#
#  dense (Dense)               (None, 1)                 17
#
# =================================================================
# Total params: 15,953
# Trainable params: 15,953
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/30
# 229/229 [==============================] - 3s 12ms/step - loss: 0.3924 - accuracy: 0.9268 - val_loss: 0.2854 - val_accuracy: 0.9291
# Epoch 2/30
# 229/229 [==============================] - 2s 11ms/step - loss: 0.2627 - accuracy: 0.9290 - val_loss: 0.2531 - val_accuracy: 0.9291
# Epoch 3/30
# 229/229 [==============================] - 2s 11ms/step - loss: 0.2367 - accuracy: 0.9290 - val_loss: 0.2317 - val_accuracy: 0.9291
# Epoch 4/30
# 229/229 [==============================] - 2s 11ms/step - loss: 0.2202 - accuracy: 0.9290 - val_loss: 0.2205 - val_accuracy: 0.9291
# Epoch 5/30
# 229/229 [==============================] - 2s 11ms/step - loss: 0.2109 - accuracy: 0.9290 - val_loss: 0.2139 - val_accuracy: 0.9291
# Epoch 6/30
# 229/229 [==============================] - 2s 11ms/step - loss: 0.2047 - accuracy: 0.9291 - val_loss: 0.2097 - val_accuracy: 0.9291
# Epoch 7/30
# 229/229 [==============================] - 2s 11ms/step - loss: 0.1991 - accuracy: 0.9294 - val_loss: 0.2059 - val_accuracy: 0.9297
# Epoch 8/30
# 229/229 [==============================] - 2s 11ms/step - loss: 0.1949 - accuracy: 0.9309 - val_loss: 0.2036 - val_accuracy: 0.9312
# Epoch 9/30
# 229/229 [==============================] - 2s 11ms/step - loss: 0.1916 - accuracy: 0.9324 - val_loss: 0.2015 - val_accuracy: 0.9315
# Epoch 10/30
# 229/229 [==============================] - 2s 11ms/step - loss: 0.1885 - accuracy: 0.9333 - val_loss: 0.2011 - val_accuracy: 0.9331
# Epoch 11/30
# 229/229 [==============================] - 2s 11ms/step - loss: 0.1864 - accuracy: 0.9341 - val_loss: 0.1995 - val_accuracy: 0.9315
# Epoch 12/30
# 229/229 [==============================] - 2s 11ms/step - loss: 0.1847 - accuracy: 0.9342 - val_loss: 0.1983 - val_accuracy: 0.9340
# Epoch 13/30
# 229/229 [==============================] - 2s 11ms/step - loss: 0.1832 - accuracy: 0.9347 - val_loss: 0.1984 - val_accuracy: 0.9331
# Epoch 14/30
# 229/229 [==============================] - 2s 11ms/step - loss: 0.1818 - accuracy: 0.9348 - val_loss: 0.1980 - val_accuracy: 0.9349
# Epoch 15/30
# 229/229 [==============================] - 2s 11ms/step - loss: 0.1805 - accuracy: 0.9356 - val_loss: 0.1963 - val_accuracy: 0.9346
# Epoch 16/30
# 229/229 [==============================] - 2s 11ms/step - loss: 0.1792 - accuracy: 0.9356 - val_loss: 0.1963 - val_accuracy: 0.9346
# Epoch 17/30
# 229/229 [==============================] - 2s 11ms/step - loss: 0.1782 - accuracy: 0.9358 - val_loss: 0.1965 - val_accuracy: 0.9352
# Epoch 18/30
# 229/229 [==============================] - 2s 11ms/step - loss: 0.1773 - accuracy: 0.9364 - val_loss: 0.1954 - val_accuracy: 0.9352
# Epoch 19/30
# 229/229 [==============================] - 2s 11ms/step - loss: 0.1765 - accuracy: 0.9365 - val_loss: 0.1953 - val_accuracy: 0.9343
# Epoch 20/30
# 229/229 [==============================] - 2s 11ms/step - loss: 0.1754 - accuracy: 0.9369 - val_loss: 0.1960 - val_accuracy: 0.9337
# Epoch 21/30
# 229/229 [==============================] - 2s 11ms/step - loss: 0.1750 - accuracy: 0.9368 - val_loss: 0.1962 - val_accuracy: 0.9346
# Epoch 22/30
# 229/229 [==============================] - 2s 11ms/step - loss: 0.1742 - accuracy: 0.9371 - val_loss: 0.1951 - val_accuracy: 0.9352
# Epoch 23/30
# 229/229 [==============================] - 2s 11ms/step - loss: 0.1735 - accuracy: 0.9376 - val_loss: 0.1965 - val_accuracy: 0.9346
# Epoch 24/30
# 229/229 [==============================] - 2s 11ms/step - loss: 0.1723 - accuracy: 0.9378 - val_loss: 0.1960 - val_accuracy: 0.9346
# Epoch 25/30
# 229/229 [==============================] - 2s 11ms/step - loss: 0.1716 - accuracy: 0.9377 - val_loss: 0.1954 - val_accuracy: 0.9349
# Epoch 26/30
# 229/229 [==============================] - 2s 11ms/step - loss: 0.1708 - accuracy: 0.9379 - val_loss: 0.1961 - val_accuracy: 0.9355
# INFO:tensorflow:Assets written to: ../data/models/model_global_24+12_careunits/assets
#     ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#     Predicting using 'global' model...
# 205/205 [==============================] - 1s 2ms/step
#     Done!
# CPU times: user 1min 22s, sys: 7.86 s, total: 1min 30s
# Wall time: 1min 29s

# %%
metrics_global_24_careunits_df
# Out:
#             AUC       PPV  Specificity
# CCU    0.866500  0.221719     0.812432
# CSRU   0.889536  0.101010     0.872766
# MICU   0.828538  0.224561     0.675159
# SICU   0.853458  0.201299     0.735768
# TSICU  0.866083  0.215686     0.797724
# Macro  0.860823  0.192855     0.778770
# Micro  0.863960  0.202732     0.759993

# %% [markdown]
# Now, let's repeat the prediction task but this time using the groups fetched in an unsupervised way from step 1 proposed by the authors in the paper:

# %%
# %%time
metrics_global_24_unsupervised_df = run_mortality_prediction_task(model_type='global', cutoff_hours=24, gap_hours=12,
                                                                  cohort_criteria_to_select='unsupervised', cohort_unsupervised_filename='../data/unsupervised_clusters_24.npy')
# Out:
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Preparing the data
# --------------------------------------------------------------------------------
#     Loading data from MIMIC-Extract pipeline...
#     Adding SAPS II score to static dataset...
#     Adding mortality columns to static dataset...
#     Discretizing X...
#         X.shape: (2200954, 33), X.subject_id.nunique(): 34472
#         X_discrete.shape: (2200954, 225), X_discrete.subject_id.nunique(): 34472
#     Keep only X_discrete[X_discrete.hours_in < 24]...
#         New X_discrete.shape: (808539, 223), new X_discrete.subject_id.nunique(): 34472
#     Padding patients with less than 24 hours of data...
#     Merging dataframes to create X_full...
#     Mortality per careunit...
#         MICU: 1138 out of 11403
#         SICU: 409 out of 5187
#         CCU: 344 out of 4907
#         CSRU: 139 out of 6971
#         TSICU: 291 out of 4245
#     Final shape of X: (32713, 24, 232)
#     Number of positive samples: 2321
#     Done!
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Running the Mortality Prediction Task
# --------------------------------------------------------------------------------
#     Splitting data into train/validation/test sets...
#     Calculating number of training samples in cohort...
#         # of patients in cohort 0 is 2888
#         # of patients in cohort 1 is 12995
#         # of patients in cohort 2 is 7015
#     ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#     Training 'global' model...
# Model: "single_task_learning_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 16)                15936
#
#  dense (Dense)               (None, 1)                 17
#
# =================================================================
# Total params: 15,953
# Trainable params: 15,953
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/30
# 229/229 [==============================] - 3s 11ms/step - loss: 0.3924 - accuracy: 0.9268 - val_loss: 0.2854 - val_accuracy: 0.9291
# Epoch 2/30
# 229/229 [==============================] - 2s 11ms/step - loss: 0.2627 - accuracy: 0.9290 - val_loss: 0.2531 - val_accuracy: 0.9291
# Epoch 3/30
# 229/229 [==============================] - 2s 11ms/step - loss: 0.2367 - accuracy: 0.9290 - val_loss: 0.2317 - val_accuracy: 0.9291
# Epoch 4/30
# 229/229 [==============================] - 2s 11ms/step - loss: 0.2202 - accuracy: 0.9290 - val_loss: 0.2205 - val_accuracy: 0.9291
# Epoch 5/30
# 229/229 [==============================] - 2s 11ms/step - loss: 0.2109 - accuracy: 0.9290 - val_loss: 0.2139 - val_accuracy: 0.9291
# Epoch 6/30
# 229/229 [==============================] - 2s 11ms/step - loss: 0.2047 - accuracy: 0.9291 - val_loss: 0.2097 - val_accuracy: 0.9291
# Epoch 7/30
# 229/229 [==============================] - 2s 11ms/step - loss: 0.1991 - accuracy: 0.9294 - val_loss: 0.2059 - val_accuracy: 0.9297
# Epoch 8/30
# 229/229 [==============================] - 2s 11ms/step - loss: 0.1949 - accuracy: 0.9309 - val_loss: 0.2036 - val_accuracy: 0.9312
# Epoch 9/30
# 229/229 [==============================] - 2s 11ms/step - loss: 0.1916 - accuracy: 0.9324 - val_loss: 0.2015 - val_accuracy: 0.9315
# Epoch 10/30
# 229/229 [==============================] - 2s 11ms/step - loss: 0.1885 - accuracy: 0.9333 - val_loss: 0.2011 - val_accuracy: 0.9331
# Epoch 11/30
# 229/229 [==============================] - 2s 11ms/step - loss: 0.1864 - accuracy: 0.9341 - val_loss: 0.1995 - val_accuracy: 0.9315
# Epoch 12/30
# 229/229 [==============================] - 2s 11ms/step - loss: 0.1847 - accuracy: 0.9342 - val_loss: 0.1983 - val_accuracy: 0.9340
# Epoch 13/30
# 229/229 [==============================] - 2s 11ms/step - loss: 0.1832 - accuracy: 0.9347 - val_loss: 0.1984 - val_accuracy: 0.9331
# Epoch 14/30
# 229/229 [==============================] - 2s 11ms/step - loss: 0.1818 - accuracy: 0.9348 - val_loss: 0.1980 - val_accuracy: 0.9349
# Epoch 15/30
# 229/229 [==============================] - 2s 11ms/step - loss: 0.1805 - accuracy: 0.9356 - val_loss: 0.1963 - val_accuracy: 0.9346
# Epoch 16/30
# 229/229 [==============================] - 2s 11ms/step - loss: 0.1792 - accuracy: 0.9356 - val_loss: 0.1963 - val_accuracy: 0.9346
# Epoch 17/30
# 229/229 [==============================] - 2s 11ms/step - loss: 0.1782 - accuracy: 0.9358 - val_loss: 0.1965 - val_accuracy: 0.9352
# Epoch 18/30
# 229/229 [==============================] - 2s 11ms/step - loss: 0.1773 - accuracy: 0.9364 - val_loss: 0.1954 - val_accuracy: 0.9352
# Epoch 19/30
# 229/229 [==============================] - 2s 11ms/step - loss: 0.1765 - accuracy: 0.9365 - val_loss: 0.1953 - val_accuracy: 0.9343
# Epoch 20/30
# 229/229 [==============================] - 2s 11ms/step - loss: 0.1754 - accuracy: 0.9369 - val_loss: 0.1960 - val_accuracy: 0.9337
# Epoch 21/30
# 229/229 [==============================] - 2s 11ms/step - loss: 0.1750 - accuracy: 0.9368 - val_loss: 0.1962 - val_accuracy: 0.9346
# Epoch 22/30
# 229/229 [==============================] - 2s 11ms/step - loss: 0.1742 - accuracy: 0.9371 - val_loss: 0.1951 - val_accuracy: 0.9352
# Epoch 23/30
# 229/229 [==============================] - 2s 11ms/step - loss: 0.1735 - accuracy: 0.9376 - val_loss: 0.1965 - val_accuracy: 0.9346
# Epoch 24/30
# 229/229 [==============================] - 2s 11ms/step - loss: 0.1723 - accuracy: 0.9378 - val_loss: 0.1960 - val_accuracy: 0.9346
# Epoch 25/30
# 229/229 [==============================] - 3s 11ms/step - loss: 0.1716 - accuracy: 0.9377 - val_loss: 0.1954 - val_accuracy: 0.9349
# Epoch 26/30
# 229/229 [==============================] - 3s 11ms/step - loss: 0.1708 - accuracy: 0.9379 - val_loss: 0.1961 - val_accuracy: 0.9355
# INFO:tensorflow:Assets written to: ../data/models/model_global_24+12_unsupervised/assets
#     ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#     Predicting using 'global' model...
# 205/205 [==============================] - 1s 2ms/step
#     Done!
# CPU times: user 1min 22s, sys: 7.85 s, total: 1min 30s
# Wall time: 1min 29s

# %%
metrics_global_24_unsupervised_df
# Out:
#             AUC       PPV  Specificity
# 0      0.844072  0.221774     0.739541
# 1      0.875076  0.194501     0.773935
# 2      0.851186  0.205342     0.741164
# Macro  0.856778  0.207206     0.751547
# Micro  0.863960  0.202732     0.759993

# %% [markdown]
# ### 3.2. In-Hospital Mortality Prediction – Baseline (*Global*) Model at 48 Hours

# %% [markdown]
# Let's now run the mortality prediction task using the *global* model (baseline) in the 48 hour experiment setting. In this experiment, the cutoff period is 48 hours and the gap period is 24 hours, meaning model can only feed from patient data collected during the first 48 hours of the ICU stay, and predict mortality 72 hours after patient goes into the ICU to avoid label leakage. In terms of the cohort type, let's go with careunits first:

# %%
# %%time
metrics_global_48_careunits_df = run_mortality_prediction_task(model_type='global', cutoff_hours=48, gap_hours=24, cohort_criteria_to_select='careunits')
# Out:
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Preparing the data
# --------------------------------------------------------------------------------
#     Loading data from MIMIC-Extract pipeline...
#     Adding SAPS II score to static dataset...
#     Adding mortality columns to static dataset...
#     Discretizing X...
#         X.shape: (2200954, 33), X.subject_id.nunique(): 34472
#         X_discrete.shape: (2200954, 225), X_discrete.subject_id.nunique(): 34472
#     Keep only X_discrete[X_discrete.hours_in < 48]...
#         New X_discrete.shape: (1349653, 223), new X_discrete.subject_id.nunique(): 34472
#     Padding patients with less than 48 hours of data...
#     Merging dataframes to create X_full...
#     Mortality per careunit...
#         MICU: 866 out of 10409
#         SICU: 303 out of 4815
#         CCU: 258 out of 4403
#         CSRU: 110 out of 6865
#         TSICU: 202 out of 3950
#     Final shape of X: (30442, 48, 232)
#     Number of positive samples: 1739
#     Done!
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Running the Mortality Prediction Task
# --------------------------------------------------------------------------------
#     Splitting data into train/validation/test sets...
#     Calculating number of training samples in cohort...
#         # of patients in cohort CCU is 3052
#         # of patients in cohort CSRU is 4806
#         # of patients in cohort MICU is 7309
#         # of patients in cohort SICU is 3358
#         # of patients in cohort TSICU is 2783
#     ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#     Training 'global' model...
# Model: "single_task_learning_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 16)                15936
#
#  dense (Dense)               (None, 1)                 17
#
# =================================================================
# Total params: 15,953
# Trainable params: 15,953
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/30
# 214/214 [==============================] - 6s 22ms/step - loss: 0.4546 - accuracy: 0.9323 - val_loss: 0.3341 - val_accuracy: 0.9429
# Epoch 2/30
# 214/214 [==============================] - 4s 21ms/step - loss: 0.2658 - accuracy: 0.9429 - val_loss: 0.2324 - val_accuracy: 0.9429
# Epoch 3/30
# 214/214 [==============================] - 4s 21ms/step - loss: 0.2189 - accuracy: 0.9428 - val_loss: 0.2132 - val_accuracy: 0.9429
# Epoch 4/30
# 214/214 [==============================] - 4s 20ms/step - loss: 0.2065 - accuracy: 0.9429 - val_loss: 0.2045 - val_accuracy: 0.9429
# Epoch 5/30
# 214/214 [==============================] - 4s 20ms/step - loss: 0.1994 - accuracy: 0.9429 - val_loss: 0.1993 - val_accuracy: 0.9429
# Epoch 6/30
# 214/214 [==============================] - 4s 21ms/step - loss: 0.1943 - accuracy: 0.9429 - val_loss: 0.1940 - val_accuracy: 0.9429
# Epoch 7/30
# 214/214 [==============================] - 4s 20ms/step - loss: 0.1900 - accuracy: 0.9429 - val_loss: 0.1896 - val_accuracy: 0.9429
# Epoch 8/30
# 214/214 [==============================] - 4s 20ms/step - loss: 0.1855 - accuracy: 0.9429 - val_loss: 0.1847 - val_accuracy: 0.9429
# Epoch 9/30
# 214/214 [==============================] - 4s 20ms/step - loss: 0.1810 - accuracy: 0.9429 - val_loss: 0.1805 - val_accuracy: 0.9429
# Epoch 10/30
# 214/214 [==============================] - 4s 20ms/step - loss: 0.1765 - accuracy: 0.9430 - val_loss: 0.1768 - val_accuracy: 0.9432
# Epoch 11/30
# 214/214 [==============================] - 4s 20ms/step - loss: 0.1727 - accuracy: 0.9432 - val_loss: 0.1712 - val_accuracy: 0.9442
# Epoch 12/30
# 214/214 [==============================] - 4s 20ms/step - loss: 0.1698 - accuracy: 0.9442 - val_loss: 0.1703 - val_accuracy: 0.9435
# Epoch 13/30
# 214/214 [==============================] - 4s 20ms/step - loss: 0.1670 - accuracy: 0.9448 - val_loss: 0.1673 - val_accuracy: 0.9435
# Epoch 14/30
# 214/214 [==============================] - 4s 20ms/step - loss: 0.1642 - accuracy: 0.9455 - val_loss: 0.1660 - val_accuracy: 0.9445
# Epoch 15/30
# 214/214 [==============================] - 4s 20ms/step - loss: 0.1624 - accuracy: 0.9458 - val_loss: 0.1647 - val_accuracy: 0.9445
# Epoch 16/30
# 214/214 [==============================] - 4s 20ms/step - loss: 0.1603 - accuracy: 0.9470 - val_loss: 0.1640 - val_accuracy: 0.9448
# Epoch 17/30
# 214/214 [==============================] - 4s 20ms/step - loss: 0.1591 - accuracy: 0.9469 - val_loss: 0.1645 - val_accuracy: 0.9442
# Epoch 18/30
# 214/214 [==============================] - 4s 20ms/step - loss: 0.1575 - accuracy: 0.9474 - val_loss: 0.1646 - val_accuracy: 0.9452
# Epoch 19/30
# 214/214 [==============================] - 4s 20ms/step - loss: 0.1564 - accuracy: 0.9479 - val_loss: 0.1638 - val_accuracy: 0.9452
# Epoch 20/30
# 214/214 [==============================] - 4s 20ms/step - loss: 0.1549 - accuracy: 0.9480 - val_loss: 0.1613 - val_accuracy: 0.9455
# Epoch 21/30
# 214/214 [==============================] - 4s 21ms/step - loss: 0.1544 - accuracy: 0.9480 - val_loss: 0.1607 - val_accuracy: 0.9461
# Epoch 22/30
# 214/214 [==============================] - 5s 21ms/step - loss: 0.1533 - accuracy: 0.9484 - val_loss: 0.1622 - val_accuracy: 0.9461
# Epoch 23/30
# 214/214 [==============================] - 5s 21ms/step - loss: 0.1525 - accuracy: 0.9487 - val_loss: 0.1602 - val_accuracy: 0.9468
# Epoch 24/30
# 214/214 [==============================] - 4s 21ms/step - loss: 0.1512 - accuracy: 0.9489 - val_loss: 0.1602 - val_accuracy: 0.9471
# Epoch 25/30
# 214/214 [==============================] - 4s 21ms/step - loss: 0.1510 - accuracy: 0.9493 - val_loss: 0.1618 - val_accuracy: 0.9455
# Epoch 26/30
# 214/214 [==============================] - 4s 21ms/step - loss: 0.1499 - accuracy: 0.9495 - val_loss: 0.1619 - val_accuracy: 0.9458
# Epoch 27/30
# 214/214 [==============================] - 4s 20ms/step - loss: 0.1491 - accuracy: 0.9496 - val_loss: 0.1600 - val_accuracy: 0.9465
# Epoch 28/30
# 214/214 [==============================] - 4s 20ms/step - loss: 0.1489 - accuracy: 0.9497 - val_loss: 0.1604 - val_accuracy: 0.9455
# Epoch 29/30
# 214/214 [==============================] - 4s 20ms/step - loss: 0.1474 - accuracy: 0.9501 - val_loss: 0.1600 - val_accuracy: 0.9465
# Epoch 30/30
# 214/214 [==============================] - 4s 20ms/step - loss: 0.1473 - accuracy: 0.9494 - val_loss: 0.1598 - val_accuracy: 0.9471
# INFO:tensorflow:Assets written to: ../data/models/model_global_48+24_careunits/assets
#     ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#     Predicting using 'global' model...
# 191/191 [==============================] - 1s 4ms/step
#     Done!
# CPU times: user 2min 37s, sys: 14 s, total: 2min 51s
# Wall time: 2min 50s

# %%
metrics_global_48_careunits_df
# Out:
#             AUC       PPV  Specificity
# CCU    0.838684  0.181452     0.762850
# CSRU   0.928321  0.066667     0.863158
# MICU   0.824743  0.184532     0.684514
# SICU   0.857993  0.206897     0.796685
# TSICU  0.803798  0.109589     0.651007
# Macro  0.850708  0.149827     0.751643
# Micro  0.853582  0.154662     0.736283

# %% [markdown]
# Now, let's repeat the prediction task but this time using the groups fetched in an unsupervised way from step 1 proposed by the authors in the paper:

# %%
# %%time
metrics_global_48_unsupervised_df = run_mortality_prediction_task(model_type='global', cutoff_hours=48, gap_hours=24,
                                                                  cohort_criteria_to_select='unsupervised', cohort_unsupervised_filename='../data/unsupervised_clusters_48.npy')
# Out:
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Preparing the data
# --------------------------------------------------------------------------------
#     Loading data from MIMIC-Extract pipeline...
#     Adding SAPS II score to static dataset...
#     Adding mortality columns to static dataset...
#     Discretizing X...
#         X.shape: (2200954, 33), X.subject_id.nunique(): 34472
#         X_discrete.shape: (2200954, 225), X_discrete.subject_id.nunique(): 34472
#     Keep only X_discrete[X_discrete.hours_in < 48]...
#         New X_discrete.shape: (1349653, 223), new X_discrete.subject_id.nunique(): 34472
#     Padding patients with less than 48 hours of data...
#     Merging dataframes to create X_full...
#     Mortality per careunit...
#         MICU: 866 out of 10409
#         SICU: 303 out of 4815
#         CCU: 258 out of 4403
#         CSRU: 110 out of 6865
#         TSICU: 202 out of 3950
#     Final shape of X: (30442, 48, 232)
#     Number of positive samples: 1739
#     Done!
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Running the Mortality Prediction Task
# --------------------------------------------------------------------------------
#     Splitting data into train/validation/test sets...
#     Calculating number of training samples in cohort...
#         # of patients in cohort 0 is 9125
#         # of patients in cohort 1 is 12183
#     ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#     Training 'global' model...
# Model: "single_task_learning_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 16)                15936
#
#  dense (Dense)               (None, 1)                 17
#
# =================================================================
# Total params: 15,953
# Trainable params: 15,953
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/30
# 214/214 [==============================] - 5s 22ms/step - loss: 0.4546 - accuracy: 0.9323 - val_loss: 0.3341 - val_accuracy: 0.9429
# Epoch 2/30
# 214/214 [==============================] - 4s 21ms/step - loss: 0.2658 - accuracy: 0.9429 - val_loss: 0.2324 - val_accuracy: 0.9429
# Epoch 3/30
# 214/214 [==============================] - 4s 20ms/step - loss: 0.2189 - accuracy: 0.9428 - val_loss: 0.2132 - val_accuracy: 0.9429
# Epoch 4/30
# 214/214 [==============================] - 4s 20ms/step - loss: 0.2065 - accuracy: 0.9429 - val_loss: 0.2045 - val_accuracy: 0.9429
# Epoch 5/30
# 214/214 [==============================] - 4s 20ms/step - loss: 0.1994 - accuracy: 0.9429 - val_loss: 0.1993 - val_accuracy: 0.9429
# Epoch 6/30
# 214/214 [==============================] - 4s 20ms/step - loss: 0.1943 - accuracy: 0.9429 - val_loss: 0.1940 - val_accuracy: 0.9429
# Epoch 7/30
# 214/214 [==============================] - 4s 20ms/step - loss: 0.1900 - accuracy: 0.9429 - val_loss: 0.1896 - val_accuracy: 0.9429
# Epoch 8/30
# 214/214 [==============================] - 4s 20ms/step - loss: 0.1855 - accuracy: 0.9429 - val_loss: 0.1847 - val_accuracy: 0.9429
# Epoch 9/30
# 214/214 [==============================] - 4s 20ms/step - loss: 0.1810 - accuracy: 0.9429 - val_loss: 0.1805 - val_accuracy: 0.9429
# Epoch 10/30
# 214/214 [==============================] - 4s 20ms/step - loss: 0.1765 - accuracy: 0.9430 - val_loss: 0.1768 - val_accuracy: 0.9432
# Epoch 11/30
# 214/214 [==============================] - 4s 21ms/step - loss: 0.1727 - accuracy: 0.9432 - val_loss: 0.1712 - val_accuracy: 0.9442
# Epoch 12/30
# 214/214 [==============================] - 4s 21ms/step - loss: 0.1698 - accuracy: 0.9442 - val_loss: 0.1703 - val_accuracy: 0.9435
# Epoch 13/30
# 214/214 [==============================] - 4s 20ms/step - loss: 0.1670 - accuracy: 0.9448 - val_loss: 0.1673 - val_accuracy: 0.9435
# Epoch 14/30
# 214/214 [==============================] - 4s 21ms/step - loss: 0.1642 - accuracy: 0.9455 - val_loss: 0.1660 - val_accuracy: 0.9445
# Epoch 15/30
# 214/214 [==============================] - 4s 20ms/step - loss: 0.1624 - accuracy: 0.9458 - val_loss: 0.1647 - val_accuracy: 0.9445
# Epoch 16/30
# 214/214 [==============================] - 4s 21ms/step - loss: 0.1603 - accuracy: 0.9470 - val_loss: 0.1640 - val_accuracy: 0.9448
# Epoch 17/30
# 214/214 [==============================] - 4s 21ms/step - loss: 0.1591 - accuracy: 0.9469 - val_loss: 0.1645 - val_accuracy: 0.9442
# Epoch 18/30
# 214/214 [==============================] - 4s 21ms/step - loss: 0.1575 - accuracy: 0.9474 - val_loss: 0.1646 - val_accuracy: 0.9452
# Epoch 19/30
# 214/214 [==============================] - 4s 21ms/step - loss: 0.1564 - accuracy: 0.9479 - val_loss: 0.1638 - val_accuracy: 0.9452
# Epoch 20/30
# 214/214 [==============================] - 4s 20ms/step - loss: 0.1549 - accuracy: 0.9480 - val_loss: 0.1613 - val_accuracy: 0.9455
# Epoch 21/30
# 214/214 [==============================] - 4s 20ms/step - loss: 0.1544 - accuracy: 0.9480 - val_loss: 0.1607 - val_accuracy: 0.9461
# Epoch 22/30
# 214/214 [==============================] - 4s 20ms/step - loss: 0.1533 - accuracy: 0.9484 - val_loss: 0.1622 - val_accuracy: 0.9461
# Epoch 23/30
# 214/214 [==============================] - 4s 21ms/step - loss: 0.1525 - accuracy: 0.9487 - val_loss: 0.1602 - val_accuracy: 0.9468
# Epoch 24/30
# 214/214 [==============================] - 4s 21ms/step - loss: 0.1512 - accuracy: 0.9489 - val_loss: 0.1602 - val_accuracy: 0.9471
# Epoch 25/30
# 214/214 [==============================] - 4s 21ms/step - loss: 0.1510 - accuracy: 0.9493 - val_loss: 0.1618 - val_accuracy: 0.9455
# Epoch 26/30
# 214/214 [==============================] - 4s 21ms/step - loss: 0.1499 - accuracy: 0.9495 - val_loss: 0.1619 - val_accuracy: 0.9458
# Epoch 27/30
# 214/214 [==============================] - 4s 21ms/step - loss: 0.1491 - accuracy: 0.9496 - val_loss: 0.1600 - val_accuracy: 0.9465
# Epoch 28/30
# 214/214 [==============================] - 4s 20ms/step - loss: 0.1489 - accuracy: 0.9497 - val_loss: 0.1604 - val_accuracy: 0.9455
# Epoch 29/30
# 214/214 [==============================] - 4s 21ms/step - loss: 0.1474 - accuracy: 0.9501 - val_loss: 0.1600 - val_accuracy: 0.9465
# Epoch 30/30
# 214/214 [==============================] - 4s 20ms/step - loss: 0.1473 - accuracy: 0.9494 - val_loss: 0.1598 - val_accuracy: 0.9471
# INFO:tensorflow:Assets written to: ../data/models/model_global_48+24_unsupervised/assets
#     ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#     Predicting using 'global' model...
# 191/191 [==============================] - 1s 4ms/step
#     Done!
# CPU times: user 2min 37s, sys: 14.1 s, total: 2min 51s
# Wall time: 2min 50s

# %%
metrics_global_48_unsupervised_df
# Out:
#             AUC       PPV  Specificity
# 0      0.870691  0.130168     0.773975
# 1      0.835444  0.169312     0.708178
# Macro  0.853068  0.149740     0.741077
# Micro  0.853582  0.154662     0.736283

# %% [markdown]
# ### 3.3. In-Hospital Mortality Prediction – Multi-Task Learning Model at 24 Hours

# %% [markdown]
# Let's now run the mortality prediction task using the multi-task learning model in the 48 hour experiment setting. In this experiment, the cutoff period is 24 hours and the gap period is 12 hours, meaning model can only feed from patient data collected during the first 24 hours of the ICU stay, and predict mortality 36 hours after patient goes into the ICU to avoid label leakage. In terms of the cohort type, let's go with careunits first:

# %%
# %%time
metrics_mtl_24_careunits_df = run_mortality_prediction_task(model_type='multitask', cutoff_hours=24, gap_hours=12, cohort_criteria_to_select='careunits')
# Out:
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Preparing the data
# --------------------------------------------------------------------------------
#     Loading data from MIMIC-Extract pipeline...
#     Adding SAPS II score to static dataset...
#     Adding mortality columns to static dataset...
#     Discretizing X...
#         X.shape: (2200954, 33), X.subject_id.nunique(): 34472
#         X_discrete.shape: (2200954, 225), X_discrete.subject_id.nunique(): 34472
#     Keep only X_discrete[X_discrete.hours_in < 24]...
#         New X_discrete.shape: (808539, 223), new X_discrete.subject_id.nunique(): 34472
#     Padding patients with less than 24 hours of data...
#     Merging dataframes to create X_full...
#     Mortality per careunit...
#         MICU: 1138 out of 11403
#         SICU: 409 out of 5187
#         CCU: 344 out of 4907
#         CSRU: 139 out of 6971
#         TSICU: 291 out of 4245
#     Final shape of X: (32713, 24, 232)
#     Number of positive samples: 2321
#     Done!
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Running the Mortality Prediction Task
# --------------------------------------------------------------------------------
#     Splitting data into train/validation/test sets...
#     Calculating number of training samples in cohort...
#         # of patients in cohort CCU is 3464
#         # of patients in cohort CSRU is 4848
#         # of patients in cohort MICU is 7912
#         # of patients in cohort SICU is 3696
#         # of patients in cohort TSICU is 2978
#     ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#     Training 'multitask' model...
# Model: "multitask_learning_model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input (InputLayer)             [(None, 24, 232)]    0           []
#
#  lstm (LSTM)                    (None, 16)           15936       ['input[0][0]']
#
#  CCU (Dense)                    (None, 1)            17          ['lstm[0][0]']
#
#  CSRU (Dense)                   (None, 1)            17          ['lstm[0][0]']
#
#  MICU (Dense)                   (None, 1)            17          ['lstm[0][0]']
#
#  SICU (Dense)                   (None, 1)            17          ['lstm[0][0]']
#
#  TSICU (Dense)                  (None, 1)            17          ['lstm[0][0]']
#
# ==================================================================================================
# Total params: 16,021
# Trainable params: 16,021
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None
# Epoch 1/30
# 229/229 [==============================] - 4s 14ms/step - loss: 0.4810 - CCU_loss: 0.0675 - CSRU_loss: 0.0760 - MICU_loss: 0.1920 - SICU_loss: 0.0864 - TSICU_loss: 0.0592 - CCU_accuracy: 0.9258 - CSRU_accuracy: 0.9244 - MICU_accuracy: 0.7881 - SICU_accuracy: 0.7978 - TSICU_accuracy: 0.9226 - val_loss: 1.5659 - val_CCU_loss: 0.3838 - val_CSRU_loss: 0.2760 - val_MICU_loss: 0.3103 - val_SICU_loss: 0.3153 - val_TSICU_loss: 0.2805 - val_CCU_accuracy: 0.9291 - val_CSRU_accuracy: 0.9291 - val_MICU_accuracy: 0.9288 - val_SICU_accuracy: 0.9285 - val_TSICU_accuracy: 0.9291
# Epoch 2/30
# 229/229 [==============================] - 3s 12ms/step - loss: 0.2736 - CCU_loss: 0.0500 - CSRU_loss: 0.0250 - MICU_loss: 0.1166 - SICU_loss: 0.0462 - TSICU_loss: 0.0358 - CCU_accuracy: 0.9290 - CSRU_accuracy: 0.9290 - MICU_accuracy: 0.9290 - SICU_accuracy: 0.9289 - TSICU_accuracy: 0.9290 - val_loss: 1.3388 - val_CCU_loss: 0.2869 - val_CSRU_loss: 0.2548 - val_MICU_loss: 0.2602 - val_SICU_loss: 0.2826 - val_TSICU_loss: 0.2543 - val_CCU_accuracy: 0.9291 - val_CSRU_accuracy: 0.9291 - val_MICU_accuracy: 0.9291 - val_SICU_accuracy: 0.9285 - val_TSICU_accuracy: 0.9291
# Epoch 3/30
# 229/229 [==============================] - 3s 12ms/step - loss: 0.2410 - CCU_loss: 0.0408 - CSRU_loss: 0.0198 - MICU_loss: 0.1059 - SICU_loss: 0.0418 - TSICU_loss: 0.0327 - CCU_accuracy: 0.9291 - CSRU_accuracy: 0.9290 - MICU_accuracy: 0.9290 - SICU_accuracy: 0.9290 - TSICU_accuracy: 0.9290 - val_loss: 1.2430 - val_CCU_loss: 0.2629 - val_CSRU_loss: 0.2545 - val_MICU_loss: 0.2338 - val_SICU_loss: 0.2515 - val_TSICU_loss: 0.2403 - val_CCU_accuracy: 0.9291 - val_CSRU_accuracy: 0.9291 - val_MICU_accuracy: 0.9291 - val_SICU_accuracy: 0.9288 - val_TSICU_accuracy: 0.9291
# Epoch 4/30
# 229/229 [==============================] - 3s 12ms/step - loss: 0.2257 - CCU_loss: 0.0374 - CSRU_loss: 0.0181 - MICU_loss: 0.1003 - SICU_loss: 0.0393 - TSICU_loss: 0.0306 - CCU_accuracy: 0.9291 - CSRU_accuracy: 0.9290 - MICU_accuracy: 0.9290 - SICU_accuracy: 0.9290 - TSICU_accuracy: 0.9290 - val_loss: 1.1928 - val_CCU_loss: 0.2499 - val_CSRU_loss: 0.2526 - val_MICU_loss: 0.2234 - val_SICU_loss: 0.2352 - val_TSICU_loss: 0.2316 - val_CCU_accuracy: 0.9291 - val_CSRU_accuracy: 0.9291 - val_MICU_accuracy: 0.9291 - val_SICU_accuracy: 0.9288 - val_TSICU_accuracy: 0.9291
# Epoch 5/30
# 229/229 [==============================] - 3s 12ms/step - loss: 0.2167 - CCU_loss: 0.0350 - CSRU_loss: 0.0174 - MICU_loss: 0.0969 - SICU_loss: 0.0379 - TSICU_loss: 0.0295 - CCU_accuracy: 0.9292 - CSRU_accuracy: 0.9290 - MICU_accuracy: 0.9290 - SICU_accuracy: 0.9290 - TSICU_accuracy: 0.9290 - val_loss: 1.1518 - val_CCU_loss: 0.2330 - val_CSRU_loss: 0.2428 - val_MICU_loss: 0.2187 - val_SICU_loss: 0.2315 - val_TSICU_loss: 0.2258 - val_CCU_accuracy: 0.9291 - val_CSRU_accuracy: 0.9291 - val_MICU_accuracy: 0.9291 - val_SICU_accuracy: 0.9291 - val_TSICU_accuracy: 0.9291
# Epoch 6/30
# 229/229 [==============================] - 3s 12ms/step - loss: 0.2105 - CCU_loss: 0.0333 - CSRU_loss: 0.0170 - MICU_loss: 0.0946 - SICU_loss: 0.0372 - TSICU_loss: 0.0284 - CCU_accuracy: 0.9292 - CSRU_accuracy: 0.9290 - MICU_accuracy: 0.9290 - SICU_accuracy: 0.9292 - TSICU_accuracy: 0.9290 - val_loss: 1.1285 - val_CCU_loss: 0.2264 - val_CSRU_loss: 0.2372 - val_MICU_loss: 0.2152 - val_SICU_loss: 0.2275 - val_TSICU_loss: 0.2222 - val_CCU_accuracy: 0.9291 - val_CSRU_accuracy: 0.9291 - val_MICU_accuracy: 0.9291 - val_SICU_accuracy: 0.9291 - val_TSICU_accuracy: 0.9291
# Epoch 7/30
# 229/229 [==============================] - 3s 12ms/step - loss: 0.2057 - CCU_loss: 0.0322 - CSRU_loss: 0.0166 - MICU_loss: 0.0929 - SICU_loss: 0.0364 - TSICU_loss: 0.0276 - CCU_accuracy: 0.9293 - CSRU_accuracy: 0.9290 - MICU_accuracy: 0.9290 - SICU_accuracy: 0.9293 - TSICU_accuracy: 0.9290 - val_loss: 1.1108 - val_CCU_loss: 0.2215 - val_CSRU_loss: 0.2335 - val_MICU_loss: 0.2128 - val_SICU_loss: 0.2240 - val_TSICU_loss: 0.2189 - val_CCU_accuracy: 0.9291 - val_CSRU_accuracy: 0.9291 - val_MICU_accuracy: 0.9291 - val_SICU_accuracy: 0.9291 - val_TSICU_accuracy: 0.9291
# Epoch 8/30
# 229/229 [==============================] - 3s 12ms/step - loss: 0.2021 - CCU_loss: 0.0313 - CSRU_loss: 0.0162 - MICU_loss: 0.0914 - SICU_loss: 0.0362 - TSICU_loss: 0.0271 - CCU_accuracy: 0.9292 - CSRU_accuracy: 0.9290 - MICU_accuracy: 0.9290 - SICU_accuracy: 0.9293 - TSICU_accuracy: 0.9290 - val_loss: 1.0961 - val_CCU_loss: 0.2191 - val_CSRU_loss: 0.2312 - val_MICU_loss: 0.2097 - val_SICU_loss: 0.2203 - val_TSICU_loss: 0.2159 - val_CCU_accuracy: 0.9294 - val_CSRU_accuracy: 0.9291 - val_MICU_accuracy: 0.9291 - val_SICU_accuracy: 0.9294 - val_TSICU_accuracy: 0.9291
# Epoch 9/30
# 229/229 [==============================] - 3s 12ms/step - loss: 0.1992 - CCU_loss: 0.0305 - CSRU_loss: 0.0159 - MICU_loss: 0.0902 - SICU_loss: 0.0359 - TSICU_loss: 0.0266 - CCU_accuracy: 0.9292 - CSRU_accuracy: 0.9290 - MICU_accuracy: 0.9291 - SICU_accuracy: 0.9293 - TSICU_accuracy: 0.9290 - val_loss: 1.0875 - val_CCU_loss: 0.2185 - val_CSRU_loss: 0.2331 - val_MICU_loss: 0.2072 - val_SICU_loss: 0.2158 - val_TSICU_loss: 0.2129 - val_CCU_accuracy: 0.9294 - val_CSRU_accuracy: 0.9291 - val_MICU_accuracy: 0.9291 - val_SICU_accuracy: 0.9294 - val_TSICU_accuracy: 0.9291
# Epoch 10/30
# 229/229 [==============================] - 3s 12ms/step - loss: 0.1964 - CCU_loss: 0.0300 - CSRU_loss: 0.0156 - MICU_loss: 0.0892 - SICU_loss: 0.0354 - TSICU_loss: 0.0262 - CCU_accuracy: 0.9293 - CSRU_accuracy: 0.9290 - MICU_accuracy: 0.9292 - SICU_accuracy: 0.9293 - TSICU_accuracy: 0.9291 - val_loss: 1.0790 - val_CCU_loss: 0.2175 - val_CSRU_loss: 0.2312 - val_MICU_loss: 0.2058 - val_SICU_loss: 0.2135 - val_TSICU_loss: 0.2109 - val_CCU_accuracy: 0.9294 - val_CSRU_accuracy: 0.9291 - val_MICU_accuracy: 0.9291 - val_SICU_accuracy: 0.9294 - val_TSICU_accuracy: 0.9291
# Epoch 11/30
# 229/229 [==============================] - 3s 12ms/step - loss: 0.1938 - CCU_loss: 0.0294 - CSRU_loss: 0.0153 - MICU_loss: 0.0882 - SICU_loss: 0.0352 - TSICU_loss: 0.0258 - CCU_accuracy: 0.9295 - CSRU_accuracy: 0.9290 - MICU_accuracy: 0.9294 - SICU_accuracy: 0.9300 - TSICU_accuracy: 0.9292 - val_loss: 1.0711 - val_CCU_loss: 0.2168 - val_CSRU_loss: 0.2297 - val_MICU_loss: 0.2042 - val_SICU_loss: 0.2113 - val_TSICU_loss: 0.2092 - val_CCU_accuracy: 0.9294 - val_CSRU_accuracy: 0.9291 - val_MICU_accuracy: 0.9291 - val_SICU_accuracy: 0.9303 - val_TSICU_accuracy: 0.9291
# Epoch 12/30
# 229/229 [==============================] - 3s 12ms/step - loss: 0.1916 - CCU_loss: 0.0290 - CSRU_loss: 0.0150 - MICU_loss: 0.0873 - SICU_loss: 0.0349 - TSICU_loss: 0.0255 - CCU_accuracy: 0.9295 - CSRU_accuracy: 0.9291 - MICU_accuracy: 0.9295 - SICU_accuracy: 0.9307 - TSICU_accuracy: 0.9293 - val_loss: 1.0613 - val_CCU_loss: 0.2120 - val_CSRU_loss: 0.2244 - val_MICU_loss: 0.2035 - val_SICU_loss: 0.2131 - val_TSICU_loss: 0.2082 - val_CCU_accuracy: 0.9297 - val_CSRU_accuracy: 0.9291 - val_MICU_accuracy: 0.9297 - val_SICU_accuracy: 0.9303 - val_TSICU_accuracy: 0.9294
# Epoch 13/30
# 229/229 [==============================] - 3s 12ms/step - loss: 0.1894 - CCU_loss: 0.0286 - CSRU_loss: 0.0147 - MICU_loss: 0.0863 - SICU_loss: 0.0346 - TSICU_loss: 0.0251 - CCU_accuracy: 0.9297 - CSRU_accuracy: 0.9291 - MICU_accuracy: 0.9303 - SICU_accuracy: 0.9320 - TSICU_accuracy: 0.9296 - val_loss: 1.0626 - val_CCU_loss: 0.2175 - val_CSRU_loss: 0.2290 - val_MICU_loss: 0.2022 - val_SICU_loss: 0.2078 - val_TSICU_loss: 0.2062 - val_CCU_accuracy: 0.9297 - val_CSRU_accuracy: 0.9294 - val_MICU_accuracy: 0.9297 - val_SICU_accuracy: 0.9309 - val_TSICU_accuracy: 0.9297
# Epoch 14/30
# 229/229 [==============================] - 3s 12ms/step - loss: 0.1873 - CCU_loss: 0.0282 - CSRU_loss: 0.0145 - MICU_loss: 0.0856 - SICU_loss: 0.0343 - TSICU_loss: 0.0248 - CCU_accuracy: 0.9299 - CSRU_accuracy: 0.9293 - MICU_accuracy: 0.9311 - SICU_accuracy: 0.9327 - TSICU_accuracy: 0.9303 - val_loss: 1.0535 - val_CCU_loss: 0.2066 - val_CSRU_loss: 0.2144 - val_MICU_loss: 0.2044 - val_SICU_loss: 0.2189 - val_TSICU_loss: 0.2091 - val_CCU_accuracy: 0.9294 - val_CSRU_accuracy: 0.9294 - val_MICU_accuracy: 0.9315 - val_SICU_accuracy: 0.9294 - val_TSICU_accuracy: 0.9300
# Epoch 15/30
# 229/229 [==============================] - 3s 12ms/step - loss: 0.1853 - CCU_loss: 0.0279 - CSRU_loss: 0.0141 - MICU_loss: 0.0846 - SICU_loss: 0.0341 - TSICU_loss: 0.0245 - CCU_accuracy: 0.9304 - CSRU_accuracy: 0.9295 - MICU_accuracy: 0.9317 - SICU_accuracy: 0.9328 - TSICU_accuracy: 0.9312 - val_loss: 1.0462 - val_CCU_loss: 0.2098 - val_CSRU_loss: 0.2231 - val_MICU_loss: 0.2006 - val_SICU_loss: 0.2088 - val_TSICU_loss: 0.2040 - val_CCU_accuracy: 0.9297 - val_CSRU_accuracy: 0.9294 - val_MICU_accuracy: 0.9318 - val_SICU_accuracy: 0.9291 - val_TSICU_accuracy: 0.9300
# Epoch 16/30
# 229/229 [==============================] - 3s 12ms/step - loss: 0.1833 - CCU_loss: 0.0276 - CSRU_loss: 0.0140 - MICU_loss: 0.0839 - SICU_loss: 0.0336 - TSICU_loss: 0.0242 - CCU_accuracy: 0.9312 - CSRU_accuracy: 0.9298 - MICU_accuracy: 0.9322 - SICU_accuracy: 0.9322 - TSICU_accuracy: 0.9323 - val_loss: 1.0393 - val_CCU_loss: 0.2081 - val_CSRU_loss: 0.2178 - val_MICU_loss: 0.2001 - val_SICU_loss: 0.2099 - val_TSICU_loss: 0.2034 - val_CCU_accuracy: 0.9297 - val_CSRU_accuracy: 0.9297 - val_MICU_accuracy: 0.9318 - val_SICU_accuracy: 0.9294 - val_TSICU_accuracy: 0.9303
# Epoch 17/30
# 229/229 [==============================] - 3s 12ms/step - loss: 0.1815 - CCU_loss: 0.0271 - CSRU_loss: 0.0137 - MICU_loss: 0.0832 - SICU_loss: 0.0336 - TSICU_loss: 0.0239 - CCU_accuracy: 0.9314 - CSRU_accuracy: 0.9302 - MICU_accuracy: 0.9331 - SICU_accuracy: 0.9323 - TSICU_accuracy: 0.9329 - val_loss: 1.0375 - val_CCU_loss: 0.2061 - val_CSRU_loss: 0.2134 - val_MICU_loss: 0.2003 - val_SICU_loss: 0.2140 - val_TSICU_loss: 0.2038 - val_CCU_accuracy: 0.9315 - val_CSRU_accuracy: 0.9300 - val_MICU_accuracy: 0.9340 - val_SICU_accuracy: 0.9257 - val_TSICU_accuracy: 0.9303
# Epoch 18/30
# 229/229 [==============================] - 3s 12ms/step - loss: 0.1799 - CCU_loss: 0.0266 - CSRU_loss: 0.0136 - MICU_loss: 0.0825 - SICU_loss: 0.0335 - TSICU_loss: 0.0237 - CCU_accuracy: 0.9323 - CSRU_accuracy: 0.9310 - MICU_accuracy: 0.9339 - SICU_accuracy: 0.9325 - TSICU_accuracy: 0.9335 - val_loss: 1.0264 - val_CCU_loss: 0.2030 - val_CSRU_loss: 0.2118 - val_MICU_loss: 0.1986 - val_SICU_loss: 0.2099 - val_TSICU_loss: 0.2031 - val_CCU_accuracy: 0.9315 - val_CSRU_accuracy: 0.9303 - val_MICU_accuracy: 0.9334 - val_SICU_accuracy: 0.9282 - val_TSICU_accuracy: 0.9306
# Epoch 19/30
# 229/229 [==============================] - 3s 12ms/step - loss: 0.1786 - CCU_loss: 0.0263 - CSRU_loss: 0.0135 - MICU_loss: 0.0820 - SICU_loss: 0.0332 - TSICU_loss: 0.0235 - CCU_accuracy: 0.9330 - CSRU_accuracy: 0.9315 - MICU_accuracy: 0.9342 - SICU_accuracy: 0.9328 - TSICU_accuracy: 0.9341 - val_loss: 1.0243 - val_CCU_loss: 0.2059 - val_CSRU_loss: 0.2175 - val_MICU_loss: 0.1973 - val_SICU_loss: 0.2035 - val_TSICU_loss: 0.2001 - val_CCU_accuracy: 0.9322 - val_CSRU_accuracy: 0.9303 - val_MICU_accuracy: 0.9337 - val_SICU_accuracy: 0.9294 - val_TSICU_accuracy: 0.9306
# Epoch 20/30
# 229/229 [==============================] - 3s 12ms/step - loss: 0.1770 - CCU_loss: 0.0260 - CSRU_loss: 0.0133 - MICU_loss: 0.0815 - SICU_loss: 0.0329 - TSICU_loss: 0.0233 - CCU_accuracy: 0.9330 - CSRU_accuracy: 0.9320 - MICU_accuracy: 0.9344 - SICU_accuracy: 0.9329 - TSICU_accuracy: 0.9349 - val_loss: 1.0180 - val_CCU_loss: 0.2006 - val_CSRU_loss: 0.2072 - val_MICU_loss: 0.1986 - val_SICU_loss: 0.2083 - val_TSICU_loss: 0.2032 - val_CCU_accuracy: 0.9325 - val_CSRU_accuracy: 0.9306 - val_MICU_accuracy: 0.9346 - val_SICU_accuracy: 0.9276 - val_TSICU_accuracy: 0.9315
# Epoch 21/30
# 229/229 [==============================] - 3s 12ms/step - loss: 0.1761 - CCU_loss: 0.0259 - CSRU_loss: 0.0133 - MICU_loss: 0.0809 - SICU_loss: 0.0328 - TSICU_loss: 0.0232 - CCU_accuracy: 0.9335 - CSRU_accuracy: 0.9329 - MICU_accuracy: 0.9343 - SICU_accuracy: 0.9332 - TSICU_accuracy: 0.9351 - val_loss: 1.0249 - val_CCU_loss: 0.2097 - val_CSRU_loss: 0.2199 - val_MICU_loss: 0.1968 - val_SICU_loss: 0.1995 - val_TSICU_loss: 0.1990 - val_CCU_accuracy: 0.9328 - val_CSRU_accuracy: 0.9306 - val_MICU_accuracy: 0.9340 - val_SICU_accuracy: 0.9309 - val_TSICU_accuracy: 0.9318
# Epoch 22/30
# 229/229 [==============================] - 3s 12ms/step - loss: 0.1748 - CCU_loss: 0.0257 - CSRU_loss: 0.0132 - MICU_loss: 0.0804 - SICU_loss: 0.0325 - TSICU_loss: 0.0230 - CCU_accuracy: 0.9338 - CSRU_accuracy: 0.9327 - MICU_accuracy: 0.9347 - SICU_accuracy: 0.9341 - TSICU_accuracy: 0.9355 - val_loss: 1.0136 - val_CCU_loss: 0.2026 - val_CSRU_loss: 0.2102 - val_MICU_loss: 0.1966 - val_SICU_loss: 0.2045 - val_TSICU_loss: 0.1997 - val_CCU_accuracy: 0.9312 - val_CSRU_accuracy: 0.9315 - val_MICU_accuracy: 0.9349 - val_SICU_accuracy: 0.9273 - val_TSICU_accuracy: 0.9312
# Epoch 23/30
# 229/229 [==============================] - 3s 12ms/step - loss: 0.1738 - CCU_loss: 0.0257 - CSRU_loss: 0.0130 - MICU_loss: 0.0798 - SICU_loss: 0.0323 - TSICU_loss: 0.0229 - CCU_accuracy: 0.9343 - CSRU_accuracy: 0.9334 - MICU_accuracy: 0.9353 - SICU_accuracy: 0.9343 - TSICU_accuracy: 0.9358 - val_loss: 1.0133 - val_CCU_loss: 0.2053 - val_CSRU_loss: 0.2110 - val_MICU_loss: 0.1962 - val_SICU_loss: 0.2016 - val_TSICU_loss: 0.1991 - val_CCU_accuracy: 0.9312 - val_CSRU_accuracy: 0.9315 - val_MICU_accuracy: 0.9352 - val_SICU_accuracy: 0.9282 - val_TSICU_accuracy: 0.9306
# Epoch 24/30
# 229/229 [==============================] - 3s 12ms/step - loss: 0.1724 - CCU_loss: 0.0254 - CSRU_loss: 0.0129 - MICU_loss: 0.0792 - SICU_loss: 0.0322 - TSICU_loss: 0.0227 - CCU_accuracy: 0.9348 - CSRU_accuracy: 0.9337 - MICU_accuracy: 0.9350 - SICU_accuracy: 0.9342 - TSICU_accuracy: 0.9360 - val_loss: 1.0135 - val_CCU_loss: 0.2061 - val_CSRU_loss: 0.2145 - val_MICU_loss: 0.1952 - val_SICU_loss: 0.1993 - val_TSICU_loss: 0.1984 - val_CCU_accuracy: 0.9322 - val_CSRU_accuracy: 0.9315 - val_MICU_accuracy: 0.9352 - val_SICU_accuracy: 0.9300 - val_TSICU_accuracy: 0.9312
# Epoch 25/30
# 229/229 [==============================] - 3s 12ms/step - loss: 0.1715 - CCU_loss: 0.0251 - CSRU_loss: 0.0128 - MICU_loss: 0.0790 - SICU_loss: 0.0320 - TSICU_loss: 0.0225 - CCU_accuracy: 0.9349 - CSRU_accuracy: 0.9339 - MICU_accuracy: 0.9349 - SICU_accuracy: 0.9349 - TSICU_accuracy: 0.9363 - val_loss: 1.0149 - val_CCU_loss: 0.2067 - val_CSRU_loss: 0.2135 - val_MICU_loss: 0.1959 - val_SICU_loss: 0.2002 - val_TSICU_loss: 0.1986 - val_CCU_accuracy: 0.9306 - val_CSRU_accuracy: 0.9315 - val_MICU_accuracy: 0.9340 - val_SICU_accuracy: 0.9285 - val_TSICU_accuracy: 0.9300
# Epoch 26/30
# 229/229 [==============================] - 3s 12ms/step - loss: 0.1705 - CCU_loss: 0.0250 - CSRU_loss: 0.0128 - MICU_loss: 0.0785 - SICU_loss: 0.0317 - TSICU_loss: 0.0225 - CCU_accuracy: 0.9351 - CSRU_accuracy: 0.9345 - MICU_accuracy: 0.9353 - SICU_accuracy: 0.9346 - TSICU_accuracy: 0.9364 - val_loss: 1.0135 - val_CCU_loss: 0.2058 - val_CSRU_loss: 0.2132 - val_MICU_loss: 0.1959 - val_SICU_loss: 0.1998 - val_TSICU_loss: 0.1988 - val_CCU_accuracy: 0.9306 - val_CSRU_accuracy: 0.9312 - val_MICU_accuracy: 0.9340 - val_SICU_accuracy: 0.9285 - val_TSICU_accuracy: 0.9309
# Epoch 27/30
# 229/229 [==============================] - 3s 12ms/step - loss: 0.1695 - CCU_loss: 0.0248 - CSRU_loss: 0.0127 - MICU_loss: 0.0781 - SICU_loss: 0.0315 - TSICU_loss: 0.0223 - CCU_accuracy: 0.9353 - CSRU_accuracy: 0.9345 - MICU_accuracy: 0.9348 - SICU_accuracy: 0.9350 - TSICU_accuracy: 0.9363 - val_loss: 1.0088 - val_CCU_loss: 0.2003 - val_CSRU_loss: 0.2074 - val_MICU_loss: 0.1973 - val_SICU_loss: 0.2036 - val_TSICU_loss: 0.2004 - val_CCU_accuracy: 0.9300 - val_CSRU_accuracy: 0.9318 - val_MICU_accuracy: 0.9340 - val_SICU_accuracy: 0.9270 - val_TSICU_accuracy: 0.9303
# Epoch 28/30
# 229/229 [==============================] - 3s 12ms/step - loss: 0.1691 - CCU_loss: 0.0248 - CSRU_loss: 0.0127 - MICU_loss: 0.0779 - SICU_loss: 0.0315 - TSICU_loss: 0.0222 - CCU_accuracy: 0.9358 - CSRU_accuracy: 0.9348 - MICU_accuracy: 0.9351 - SICU_accuracy: 0.9354 - TSICU_accuracy: 0.9365 - val_loss: 1.0151 - val_CCU_loss: 0.2063 - val_CSRU_loss: 0.2135 - val_MICU_loss: 0.1967 - val_SICU_loss: 0.1997 - val_TSICU_loss: 0.1988 - val_CCU_accuracy: 0.9303 - val_CSRU_accuracy: 0.9315 - val_MICU_accuracy: 0.9334 - val_SICU_accuracy: 0.9294 - val_TSICU_accuracy: 0.9312
# Epoch 29/30
# 229/229 [==============================] - 3s 12ms/step - loss: 0.1682 - CCU_loss: 0.0246 - CSRU_loss: 0.0125 - MICU_loss: 0.0778 - SICU_loss: 0.0312 - TSICU_loss: 0.0221 - CCU_accuracy: 0.9362 - CSRU_accuracy: 0.9349 - MICU_accuracy: 0.9352 - SICU_accuracy: 0.9349 - TSICU_accuracy: 0.9364 - val_loss: 1.0085 - val_CCU_loss: 0.2048 - val_CSRU_loss: 0.2091 - val_MICU_loss: 0.1965 - val_SICU_loss: 0.1990 - val_TSICU_loss: 0.1992 - val_CCU_accuracy: 0.9306 - val_CSRU_accuracy: 0.9315 - val_MICU_accuracy: 0.9340 - val_SICU_accuracy: 0.9303 - val_TSICU_accuracy: 0.9312
# Epoch 30/30
# 229/229 [==============================] - 3s 12ms/step - loss: 0.1672 - CCU_loss: 0.0244 - CSRU_loss: 0.0124 - MICU_loss: 0.0771 - SICU_loss: 0.0313 - TSICU_loss: 0.0220 - CCU_accuracy: 0.9366 - CSRU_accuracy: 0.9351 - MICU_accuracy: 0.9350 - SICU_accuracy: 0.9358 - TSICU_accuracy: 0.9370 - val_loss: 1.0104 - val_CCU_loss: 0.2065 - val_CSRU_loss: 0.2105 - val_MICU_loss: 0.1961 - val_SICU_loss: 0.1984 - val_TSICU_loss: 0.1988 - val_CCU_accuracy: 0.9315 - val_CSRU_accuracy: 0.9315 - val_MICU_accuracy: 0.9337 - val_SICU_accuracy: 0.9306 - val_TSICU_accuracy: 0.9315
# INFO:tensorflow:Assets written to: ../data/models/model_multitask_24+12_careunits/assets
#     ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#     Predicting using 'multitask' model...
# 205/205 [==============================] - 1s 2ms/step
#     Done!
# CPU times: user 1min 44s, sys: 8.05 s, total: 1min 52s
# Wall time: 1min 50s

# %%
metrics_mtl_24_careunits_df
# Out:
#             AUC       PPV  Specificity
# CCU    0.858656  0.193798     0.773173
# CSRU   0.903420  0.200000     0.951394
# MICU   0.832287  0.234875     0.683978
# SICU   0.840120  0.217857     0.764769
# TSICU  0.869988  0.205607     0.785082
# Macro  0.860894  0.210428     0.791679
# Micro  0.865165  0.220238     0.784504

# %% [markdown]
# Now, let's repeat the prediction task but this time using the groups fetched in an unsupervised way from step 1 proposed by the authors in the paper:

# %%
# %%time
metrics_mtl_24_unsupervised_df = run_mortality_prediction_task(model_type='multitask', cutoff_hours=24, gap_hours=12,
                                                               cohort_criteria_to_select='unsupervised', cohort_unsupervised_filename='../data/unsupervised_clusters_24.npy')
# Out:
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Preparing the data
# --------------------------------------------------------------------------------
#     Loading data from MIMIC-Extract pipeline...
#     Adding SAPS II score to static dataset...
#     Adding mortality columns to static dataset...
#     Discretizing X...
#         X.shape: (2200954, 33), X.subject_id.nunique(): 34472
#         X_discrete.shape: (2200954, 225), X_discrete.subject_id.nunique(): 34472
#     Keep only X_discrete[X_discrete.hours_in < 24]...
#         New X_discrete.shape: (808539, 223), new X_discrete.subject_id.nunique(): 34472
#     Padding patients with less than 24 hours of data...
#     Merging dataframes to create X_full...
#     Mortality per careunit...
#         MICU: 1138 out of 11403
#         SICU: 409 out of 5187
#         CCU: 344 out of 4907
#         CSRU: 139 out of 6971
#         TSICU: 291 out of 4245
#     Final shape of X: (32713, 24, 232)
#     Number of positive samples: 2321
#     Done!
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Running the Mortality Prediction Task
# --------------------------------------------------------------------------------
#     Splitting data into train/validation/test sets...
#     Calculating number of training samples in cohort...
#         # of patients in cohort 0 is 2888
#         # of patients in cohort 1 is 12995
#         # of patients in cohort 2 is 7015
#     ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#     Training 'multitask' model...
# Model: "multitask_learning_model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input (InputLayer)             [(None, 24, 232)]    0           []
#
#  lstm (LSTM)                    (None, 16)           15936       ['input[0][0]']
#
#  0 (Dense)                      (None, 1)            17          ['lstm[0][0]']
#
#  1 (Dense)                      (None, 1)            17          ['lstm[0][0]']
#
#  2 (Dense)                      (None, 1)            17          ['lstm[0][0]']
#
# ==================================================================================================
# Total params: 15,987
# Trainable params: 15,987
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None
# Epoch 1/30
# 229/229 [==============================] - 4s 13ms/step - loss: 0.4339 - 0_loss: 0.0591 - 1_loss: 0.2262 - 2_loss: 0.1486 - 0_accuracy: 0.9245 - 1_accuracy: 0.9241 - 2_accuracy: 0.7571 - val_loss: 0.8935 - val_0_loss: 0.3171 - val_1_loss: 0.2742 - val_2_loss: 0.3022 - val_0_accuracy: 0.9291 - val_1_accuracy: 0.9291 - val_2_accuracy: 0.9288
# Epoch 2/30
# 229/229 [==============================] - 3s 12ms/step - loss: 0.2589 - 0_loss: 0.0380 - 1_loss: 0.1406 - 2_loss: 0.0804 - 0_accuracy: 0.9290 - 1_accuracy: 0.9290 - 2_accuracy: 0.9289 - val_loss: 0.7930 - val_0_loss: 0.2720 - val_1_loss: 0.2511 - val_2_loss: 0.2700 - val_0_accuracy: 0.9291 - val_1_accuracy: 0.9291 - val_2_accuracy: 0.9291
# Epoch 3/30
# 229/229 [==============================] - 3s 12ms/step - loss: 0.2389 - 0_loss: 0.0348 - 1_loss: 0.1297 - 2_loss: 0.0744 - 0_accuracy: 0.9290 - 1_accuracy: 0.9290 - 2_accuracy: 0.9290 - val_loss: 0.7313 - val_0_loss: 0.2534 - val_1_loss: 0.2341 - val_2_loss: 0.2438 - val_0_accuracy: 0.9291 - val_1_accuracy: 0.9291 - val_2_accuracy: 0.9291
# Epoch 4/30
# 229/229 [==============================] - 3s 12ms/step - loss: 0.2266 - 0_loss: 0.0329 - 1_loss: 0.1228 - 2_loss: 0.0709 - 0_accuracy: 0.9290 - 1_accuracy: 0.9290 - 2_accuracy: 0.9290 - val_loss: 0.7016 - val_0_loss: 0.2449 - val_1_loss: 0.2250 - val_2_loss: 0.2317 - val_0_accuracy: 0.9291 - val_1_accuracy: 0.9291 - val_2_accuracy: 0.9291
# Epoch 5/30
# 229/229 [==============================] - 3s 12ms/step - loss: 0.2184 - 0_loss: 0.0316 - 1_loss: 0.1178 - 2_loss: 0.0690 - 0_accuracy: 0.9290 - 1_accuracy: 0.9290 - 2_accuracy: 0.9290 - val_loss: 0.6807 - val_0_loss: 0.2332 - val_1_loss: 0.2203 - val_2_loss: 0.2273 - val_0_accuracy: 0.9291 - val_1_accuracy: 0.9291 - val_2_accuracy: 0.9291
# Epoch 6/30
# 229/229 [==============================] - 3s 12ms/step - loss: 0.2125 - 0_loss: 0.0306 - 1_loss: 0.1144 - 2_loss: 0.0674 - 0_accuracy: 0.9291 - 1_accuracy: 0.9290 - 2_accuracy: 0.9290 - val_loss: 0.6670 - val_0_loss: 0.2270 - val_1_loss: 0.2169 - val_2_loss: 0.2231 - val_0_accuracy: 0.9291 - val_1_accuracy: 0.9291 - val_2_accuracy: 0.9291
# Epoch 7/30
# 229/229 [==============================] - 3s 12ms/step - loss: 0.2077 - 0_loss: 0.0300 - 1_loss: 0.1116 - 2_loss: 0.0661 - 0_accuracy: 0.9291 - 1_accuracy: 0.9290 - 2_accuracy: 0.9290 - val_loss: 0.6568 - val_0_loss: 0.2226 - val_1_loss: 0.2151 - val_2_loss: 0.2190 - val_0_accuracy: 0.9291 - val_1_accuracy: 0.9291 - val_2_accuracy: 0.9291
# Epoch 8/30
# 229/229 [==============================] - 3s 12ms/step - loss: 0.2041 - 0_loss: 0.0293 - 1_loss: 0.1094 - 2_loss: 0.0654 - 0_accuracy: 0.9291 - 1_accuracy: 0.9291 - 2_accuracy: 0.9290 - val_loss: 0.6508 - val_0_loss: 0.2236 - val_1_loss: 0.2130 - val_2_loss: 0.2142 - val_0_accuracy: 0.9291 - val_1_accuracy: 0.9291 - val_2_accuracy: 0.9291
# Epoch 9/30
# 229/229 [==============================] - 3s 11ms/step - loss: 0.2008 - 0_loss: 0.0288 - 1_loss: 0.1075 - 2_loss: 0.0645 - 0_accuracy: 0.9291 - 1_accuracy: 0.9291 - 2_accuracy: 0.9290 - val_loss: 0.6477 - val_0_loss: 0.2272 - val_1_loss: 0.2098 - val_2_loss: 0.2106 - val_0_accuracy: 0.9291 - val_1_accuracy: 0.9291 - val_2_accuracy: 0.9291
# Epoch 10/30
# 229/229 [==============================] - 3s 11ms/step - loss: 0.1973 - 0_loss: 0.0283 - 1_loss: 0.1058 - 2_loss: 0.0633 - 0_accuracy: 0.9291 - 1_accuracy: 0.9292 - 2_accuracy: 0.9291 - val_loss: 0.6472 - val_0_loss: 0.2304 - val_1_loss: 0.2085 - val_2_loss: 0.2083 - val_0_accuracy: 0.9291 - val_1_accuracy: 0.9291 - val_2_accuracy: 0.9291
# Epoch 11/30
# 229/229 [==============================] - 3s 11ms/step - loss: 0.1946 - 0_loss: 0.0278 - 1_loss: 0.1042 - 2_loss: 0.0627 - 0_accuracy: 0.9291 - 1_accuracy: 0.9295 - 2_accuracy: 0.9291 - val_loss: 0.6432 - val_0_loss: 0.2283 - val_1_loss: 0.2080 - val_2_loss: 0.2069 - val_0_accuracy: 0.9291 - val_1_accuracy: 0.9291 - val_2_accuracy: 0.9291
# Epoch 12/30
# 229/229 [==============================] - 3s 11ms/step - loss: 0.1917 - 0_loss: 0.0275 - 1_loss: 0.1024 - 2_loss: 0.0619 - 0_accuracy: 0.9293 - 1_accuracy: 0.9299 - 2_accuracy: 0.9295 - val_loss: 0.6443 - val_0_loss: 0.2291 - val_1_loss: 0.2096 - val_2_loss: 0.2056 - val_0_accuracy: 0.9291 - val_1_accuracy: 0.9291 - val_2_accuracy: 0.9291
# Epoch 13/30
# 229/229 [==============================] - 3s 12ms/step - loss: 0.1894 - 0_loss: 0.0270 - 1_loss: 0.1010 - 2_loss: 0.0613 - 0_accuracy: 0.9294 - 1_accuracy: 0.9312 - 2_accuracy: 0.9299 - val_loss: 0.6503 - val_0_loss: 0.2392 - val_1_loss: 0.2069 - val_2_loss: 0.2042 - val_0_accuracy: 0.9291 - val_1_accuracy: 0.9297 - val_2_accuracy: 0.9297
# Epoch 14/30
# 229/229 [==============================] - 3s 11ms/step - loss: 0.1869 - 0_loss: 0.0267 - 1_loss: 0.0996 - 2_loss: 0.0606 - 0_accuracy: 0.9295 - 1_accuracy: 0.9319 - 2_accuracy: 0.9303 - val_loss: 0.6387 - val_0_loss: 0.2197 - val_1_loss: 0.2131 - val_2_loss: 0.2060 - val_0_accuracy: 0.9294 - val_1_accuracy: 0.9273 - val_2_accuracy: 0.9300
# Epoch 15/30
# 229/229 [==============================] - 3s 11ms/step - loss: 0.1851 - 0_loss: 0.0263 - 1_loss: 0.0985 - 2_loss: 0.0603 - 0_accuracy: 0.9296 - 1_accuracy: 0.9325 - 2_accuracy: 0.9306 - val_loss: 0.6468 - val_0_loss: 0.2375 - val_1_loss: 0.2070 - val_2_loss: 0.2024 - val_0_accuracy: 0.9294 - val_1_accuracy: 0.9291 - val_2_accuracy: 0.9303
# Epoch 16/30
# 229/229 [==============================] - 3s 11ms/step - loss: 0.1830 - 0_loss: 0.0260 - 1_loss: 0.0974 - 2_loss: 0.0596 - 0_accuracy: 0.9297 - 1_accuracy: 0.9325 - 2_accuracy: 0.9307 - val_loss: 0.6408 - val_0_loss: 0.2306 - val_1_loss: 0.2082 - val_2_loss: 0.2020 - val_0_accuracy: 0.9300 - val_1_accuracy: 0.9300 - val_2_accuracy: 0.9306
# Epoch 17/30
# 229/229 [==============================] - 3s 11ms/step - loss: 0.1815 - 0_loss: 0.0256 - 1_loss: 0.0967 - 2_loss: 0.0591 - 0_accuracy: 0.9298 - 1_accuracy: 0.9327 - 2_accuracy: 0.9308 - val_loss: 0.6388 - val_0_loss: 0.2270 - val_1_loss: 0.2098 - val_2_loss: 0.2020 - val_0_accuracy: 0.9306 - val_1_accuracy: 0.9288 - val_2_accuracy: 0.9306
# Epoch 18/30
# 229/229 [==============================] - 3s 11ms/step - loss: 0.1801 - 0_loss: 0.0254 - 1_loss: 0.0961 - 2_loss: 0.0586 - 0_accuracy: 0.9300 - 1_accuracy: 0.9328 - 2_accuracy: 0.9309 - val_loss: 0.6358 - val_0_loss: 0.2250 - val_1_loss: 0.2086 - val_2_loss: 0.2022 - val_0_accuracy: 0.9306 - val_1_accuracy: 0.9303 - val_2_accuracy: 0.9306
# Epoch 19/30
# 229/229 [==============================] - 3s 11ms/step - loss: 0.1791 - 0_loss: 0.0253 - 1_loss: 0.0954 - 2_loss: 0.0585 - 0_accuracy: 0.9301 - 1_accuracy: 0.9332 - 2_accuracy: 0.9314 - val_loss: 0.6478 - val_0_loss: 0.2389 - val_1_loss: 0.2069 - val_2_loss: 0.2020 - val_0_accuracy: 0.9306 - val_1_accuracy: 0.9297 - val_2_accuracy: 0.9306
# Epoch 20/30
# 229/229 [==============================] - 3s 11ms/step - loss: 0.1777 - 0_loss: 0.0250 - 1_loss: 0.0948 - 2_loss: 0.0579 - 0_accuracy: 0.9302 - 1_accuracy: 0.9338 - 2_accuracy: 0.9317 - val_loss: 0.6333 - val_0_loss: 0.2186 - val_1_loss: 0.2110 - val_2_loss: 0.2036 - val_0_accuracy: 0.9309 - val_1_accuracy: 0.9273 - val_2_accuracy: 0.9322
# Epoch 21/30
# 229/229 [==============================] - 3s 11ms/step - loss: 0.1773 - 0_loss: 0.0250 - 1_loss: 0.0943 - 2_loss: 0.0580 - 0_accuracy: 0.9306 - 1_accuracy: 0.9334 - 2_accuracy: 0.9319 - val_loss: 0.6459 - val_0_loss: 0.2385 - val_1_loss: 0.2055 - val_2_loss: 0.2020 - val_0_accuracy: 0.9312 - val_1_accuracy: 0.9300 - val_2_accuracy: 0.9309
# Epoch 22/30
# 229/229 [==============================] - 3s 12ms/step - loss: 0.1760 - 0_loss: 0.0248 - 1_loss: 0.0938 - 2_loss: 0.0575 - 0_accuracy: 0.9307 - 1_accuracy: 0.9337 - 2_accuracy: 0.9320 - val_loss: 0.6361 - val_0_loss: 0.2282 - val_1_loss: 0.2068 - val_2_loss: 0.2011 - val_0_accuracy: 0.9309 - val_1_accuracy: 0.9273 - val_2_accuracy: 0.9322
# Epoch 23/30
# 229/229 [==============================] - 3s 12ms/step - loss: 0.1753 - 0_loss: 0.0246 - 1_loss: 0.0935 - 2_loss: 0.0573 - 0_accuracy: 0.9310 - 1_accuracy: 0.9337 - 2_accuracy: 0.9324 - val_loss: 0.6454 - val_0_loss: 0.2364 - val_1_loss: 0.2069 - val_2_loss: 0.2021 - val_0_accuracy: 0.9309 - val_1_accuracy: 0.9273 - val_2_accuracy: 0.9315
# Epoch 24/30
# 229/229 [==============================] - 3s 12ms/step - loss: 0.1740 - 0_loss: 0.0246 - 1_loss: 0.0925 - 2_loss: 0.0569 - 0_accuracy: 0.9310 - 1_accuracy: 0.9341 - 2_accuracy: 0.9324 - val_loss: 0.6435 - val_0_loss: 0.2346 - val_1_loss: 0.2073 - val_2_loss: 0.2015 - val_0_accuracy: 0.9318 - val_1_accuracy: 0.9270 - val_2_accuracy: 0.9322
# INFO:tensorflow:Assets written to: ../data/models/model_multitask_24+12_unsupervised/assets
#     ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#     Predicting using 'multitask' model...
# 205/205 [==============================] - 1s 2ms/step
#     Done!
# CPU times: user 1min 22s, sys: 7.61 s, total: 1min 30s
# Wall time: 1min 29s

# %%
metrics_mtl_24_unsupervised_df
# Out:
#             AUC       PPV  Specificity
# 0      0.847291  0.225296     0.735493
# 1      0.871185  0.195122     0.773650
# 2      0.840042  0.197068     0.731920
# Macro  0.852839  0.205829     0.747021
# Micro  0.858261  0.199892     0.756374

# %% [markdown]
# ### 3.4. In-Hospital Mortality Prediction – Multi-Task Learning Model at 48 Hours

# %% [markdown]
# Let's now run the mortality prediction task using the multi-task learning model in the 48 hour experiment setting. In this experiment, the cutoff period is 48 hours and the gap period is 24 hours, meaning model can only feed from patient data collected during the first 48 hours of the ICU stay, and predict mortality 72 hours after patient goes into the ICU to avoid label leakage. In terms of the cohort type, let's go with careunits first:

# %%
# %%time
metrics_mtl_48_careunits_df = run_mortality_prediction_task(model_type='multitask', cutoff_hours=48, gap_hours=24, cohort_criteria_to_select='careunits')
# Out:
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Preparing the data
# --------------------------------------------------------------------------------
#     Loading data from MIMIC-Extract pipeline...
#     Adding SAPS II score to static dataset...
#     Adding mortality columns to static dataset...
#     Discretizing X...
#         X.shape: (2200954, 33), X.subject_id.nunique(): 34472
#         X_discrete.shape: (2200954, 225), X_discrete.subject_id.nunique(): 34472
#     Keep only X_discrete[X_discrete.hours_in < 48]...
#         New X_discrete.shape: (1349653, 223), new X_discrete.subject_id.nunique(): 34472
#     Padding patients with less than 48 hours of data...
#     Merging dataframes to create X_full...
#     Mortality per careunit...
#         MICU: 866 out of 10409
#         SICU: 303 out of 4815
#         CCU: 258 out of 4403
#         CSRU: 110 out of 6865
#         TSICU: 202 out of 3950
#     Final shape of X: (30442, 48, 232)
#     Number of positive samples: 1739
#     Done!
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Running the Mortality Prediction Task
# --------------------------------------------------------------------------------
#     Splitting data into train/validation/test sets...
#     Calculating number of training samples in cohort...
#         # of patients in cohort CCU is 3052
#         # of patients in cohort CSRU is 4806
#         # of patients in cohort MICU is 7309
#         # of patients in cohort SICU is 3358
#         # of patients in cohort TSICU is 2783
#     ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#     Training 'multitask' model...
# Model: "multitask_learning_model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input (InputLayer)             [(None, 48, 232)]    0           []
#
#  lstm (LSTM)                    (None, 16)           15936       ['input[0][0]']
#
#  CCU (Dense)                    (None, 1)            17          ['lstm[0][0]']
#
#  CSRU (Dense)                   (None, 1)            17          ['lstm[0][0]']
#
#  MICU (Dense)                   (None, 1)            17          ['lstm[0][0]']
#
#  SICU (Dense)                   (None, 1)            17          ['lstm[0][0]']
#
#  TSICU (Dense)                  (None, 1)            17          ['lstm[0][0]']
#
# ==================================================================================================
# Total params: 16,021
# Trainable params: 16,021
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None
# Epoch 1/30
# 214/214 [==============================] - 6s 23ms/step - loss: 0.5314 - CCU_loss: 0.0727 - CSRU_loss: 0.1022 - MICU_loss: 0.1999 - SICU_loss: 0.0916 - TSICU_loss: 0.0651 - CCU_accuracy: 0.9280 - CSRU_accuracy: 0.9206 - MICU_accuracy: 0.7622 - SICU_accuracy: 0.7806 - TSICU_accuracy: 0.9278 - val_loss: 1.7581 - val_CCU_loss: 0.4881 - val_CSRU_loss: 0.2832 - val_MICU_loss: 0.3416 - val_SICU_loss: 0.3355 - val_TSICU_loss: 0.3097 - val_CCU_accuracy: 0.9429 - val_CSRU_accuracy: 0.9429 - val_MICU_accuracy: 0.9399 - val_SICU_accuracy: 0.9409 - val_TSICU_accuracy: 0.9429
# Epoch 2/30
# 214/214 [==============================] - 5s 21ms/step - loss: 0.2783 - CCU_loss: 0.0662 - CSRU_loss: 0.0246 - MICU_loss: 0.1122 - SICU_loss: 0.0428 - TSICU_loss: 0.0325 - CCU_accuracy: 0.9429 - CSRU_accuracy: 0.9429 - MICU_accuracy: 0.9423 - SICU_accuracy: 0.9422 - TSICU_accuracy: 0.9429 - val_loss: 1.3684 - val_CCU_loss: 0.4036 - val_CSRU_loss: 0.2330 - val_MICU_loss: 0.2487 - val_SICU_loss: 0.2468 - val_TSICU_loss: 0.2363 - val_CCU_accuracy: 0.9429 - val_CSRU_accuracy: 0.9429 - val_MICU_accuracy: 0.9429 - val_SICU_accuracy: 0.9429 - val_TSICU_accuracy: 0.9429
# Epoch 3/30
# 214/214 [==============================] - 5s 21ms/step - loss: 0.2356 - CCU_loss: 0.0492 - CSRU_loss: 0.0204 - MICU_loss: 0.0998 - SICU_loss: 0.0383 - TSICU_loss: 0.0278 - CCU_accuracy: 0.9429 - CSRU_accuracy: 0.9429 - MICU_accuracy: 0.9429 - SICU_accuracy: 0.9428 - TSICU_accuracy: 0.9429 - val_loss: 1.2254 - val_CCU_loss: 0.3166 - val_CSRU_loss: 0.2315 - val_MICU_loss: 0.2242 - val_SICU_loss: 0.2316 - val_TSICU_loss: 0.2214 - val_CCU_accuracy: 0.9429 - val_CSRU_accuracy: 0.9429 - val_MICU_accuracy: 0.9429 - val_SICU_accuracy: 0.9429 - val_TSICU_accuracy: 0.9429
# Epoch 4/30
# 214/214 [==============================] - 5s 21ms/step - loss: 0.2118 - CCU_loss: 0.0375 - CSRU_loss: 0.0190 - MICU_loss: 0.0933 - SICU_loss: 0.0360 - TSICU_loss: 0.0260 - CCU_accuracy: 0.9429 - CSRU_accuracy: 0.9429 - MICU_accuracy: 0.9429 - SICU_accuracy: 0.9429 - TSICU_accuracy: 0.9429 - val_loss: 1.1170 - val_CCU_loss: 0.2488 - val_CSRU_loss: 0.2295 - val_MICU_loss: 0.2069 - val_SICU_loss: 0.2219 - val_TSICU_loss: 0.2099 - val_CCU_accuracy: 0.9429 - val_CSRU_accuracy: 0.9429 - val_MICU_accuracy: 0.9429 - val_SICU_accuracy: 0.9432 - val_TSICU_accuracy: 0.9429
# Epoch 5/30
# 214/214 [==============================] - 5s 22ms/step - loss: 0.1928 - CCU_loss: 0.0305 - CSRU_loss: 0.0174 - MICU_loss: 0.0871 - SICU_loss: 0.0333 - TSICU_loss: 0.0245 - CCU_accuracy: 0.9429 - CSRU_accuracy: 0.9429 - MICU_accuracy: 0.9429 - SICU_accuracy: 0.9429 - TSICU_accuracy: 0.9429 - val_loss: 1.0304 - val_CCU_loss: 0.2115 - val_CSRU_loss: 0.2185 - val_MICU_loss: 0.1941 - val_SICU_loss: 0.2091 - val_TSICU_loss: 0.1971 - val_CCU_accuracy: 0.9432 - val_CSRU_accuracy: 0.9429 - val_MICU_accuracy: 0.9429 - val_SICU_accuracy: 0.9429 - val_TSICU_accuracy: 0.9429
# Epoch 6/30
# 214/214 [==============================] - 5s 21ms/step - loss: 0.1798 - CCU_loss: 0.0270 - CSRU_loss: 0.0160 - MICU_loss: 0.0830 - SICU_loss: 0.0310 - TSICU_loss: 0.0228 - CCU_accuracy: 0.9430 - CSRU_accuracy: 0.9429 - MICU_accuracy: 0.9429 - SICU_accuracy: 0.9429 - TSICU_accuracy: 0.9429 - val_loss: 0.9756 - val_CCU_loss: 0.1986 - val_CSRU_loss: 0.2183 - val_MICU_loss: 0.1817 - val_SICU_loss: 0.1895 - val_TSICU_loss: 0.1876 - val_CCU_accuracy: 0.9432 - val_CSRU_accuracy: 0.9429 - val_MICU_accuracy: 0.9429 - val_SICU_accuracy: 0.9429 - val_TSICU_accuracy: 0.9429
# Epoch 7/30
# 214/214 [==============================] - 5s 21ms/step - loss: 0.1749 - CCU_loss: 0.0256 - CSRU_loss: 0.0153 - MICU_loss: 0.0813 - SICU_loss: 0.0308 - TSICU_loss: 0.0220 - CCU_accuracy: 0.9429 - CSRU_accuracy: 0.9429 - MICU_accuracy: 0.9429 - SICU_accuracy: 0.9429 - TSICU_accuracy: 0.9429 - val_loss: 0.9460 - val_CCU_loss: 0.1898 - val_CSRU_loss: 0.2043 - val_MICU_loss: 0.1814 - val_SICU_loss: 0.1862 - val_TSICU_loss: 0.1843 - val_CCU_accuracy: 0.9432 - val_CSRU_accuracy: 0.9429 - val_MICU_accuracy: 0.9429 - val_SICU_accuracy: 0.9429 - val_TSICU_accuracy: 0.9429
# Epoch 8/30
# 214/214 [==============================] - 5s 21ms/step - loss: 0.1704 - CCU_loss: 0.0248 - CSRU_loss: 0.0146 - MICU_loss: 0.0805 - SICU_loss: 0.0292 - TSICU_loss: 0.0213 - CCU_accuracy: 0.9430 - CSRU_accuracy: 0.9429 - MICU_accuracy: 0.9429 - SICU_accuracy: 0.9431 - TSICU_accuracy: 0.9429 - val_loss: 0.9310 - val_CCU_loss: 0.1869 - val_CSRU_loss: 0.2052 - val_MICU_loss: 0.1774 - val_SICU_loss: 0.1811 - val_TSICU_loss: 0.1804 - val_CCU_accuracy: 0.9432 - val_CSRU_accuracy: 0.9429 - val_MICU_accuracy: 0.9429 - val_SICU_accuracy: 0.9425 - val_TSICU_accuracy: 0.9429
# Epoch 9/30
# 214/214 [==============================] - 5s 22ms/step - loss: 0.1678 - CCU_loss: 0.0243 - CSRU_loss: 0.0144 - MICU_loss: 0.0795 - SICU_loss: 0.0289 - TSICU_loss: 0.0208 - CCU_accuracy: 0.9431 - CSRU_accuracy: 0.9429 - MICU_accuracy: 0.9429 - SICU_accuracy: 0.9430 - TSICU_accuracy: 0.9429 - val_loss: 0.9175 - val_CCU_loss: 0.1824 - val_CSRU_loss: 0.1985 - val_MICU_loss: 0.1774 - val_SICU_loss: 0.1811 - val_TSICU_loss: 0.1781 - val_CCU_accuracy: 0.9432 - val_CSRU_accuracy: 0.9429 - val_MICU_accuracy: 0.9429 - val_SICU_accuracy: 0.9425 - val_TSICU_accuracy: 0.9429
# Epoch 10/30
# 214/214 [==============================] - 5s 21ms/step - loss: 0.1661 - CCU_loss: 0.0238 - CSRU_loss: 0.0141 - MICU_loss: 0.0790 - SICU_loss: 0.0286 - TSICU_loss: 0.0205 - CCU_accuracy: 0.9432 - CSRU_accuracy: 0.9429 - MICU_accuracy: 0.9430 - SICU_accuracy: 0.9431 - TSICU_accuracy: 0.9430 - val_loss: 0.9151 - val_CCU_loss: 0.1823 - val_CSRU_loss: 0.2003 - val_MICU_loss: 0.1781 - val_SICU_loss: 0.1778 - val_TSICU_loss: 0.1765 - val_CCU_accuracy: 0.9429 - val_CSRU_accuracy: 0.9429 - val_MICU_accuracy: 0.9425 - val_SICU_accuracy: 0.9425 - val_TSICU_accuracy: 0.9429
# Epoch 11/30
# 214/214 [==============================] - 5s 22ms/step - loss: 0.1644 - CCU_loss: 0.0235 - CSRU_loss: 0.0138 - MICU_loss: 0.0784 - SICU_loss: 0.0285 - TSICU_loss: 0.0202 - CCU_accuracy: 0.9433 - CSRU_accuracy: 0.9429 - MICU_accuracy: 0.9428 - SICU_accuracy: 0.9432 - TSICU_accuracy: 0.9430 - val_loss: 0.9091 - val_CCU_loss: 0.1834 - val_CSRU_loss: 0.2017 - val_MICU_loss: 0.1733 - val_SICU_loss: 0.1748 - val_TSICU_loss: 0.1761 - val_CCU_accuracy: 0.9432 - val_CSRU_accuracy: 0.9429 - val_MICU_accuracy: 0.9425 - val_SICU_accuracy: 0.9429 - val_TSICU_accuracy: 0.9429
# Epoch 12/30
# 214/214 [==============================] - 5s 21ms/step - loss: 0.1635 - CCU_loss: 0.0234 - CSRU_loss: 0.0137 - MICU_loss: 0.0778 - SICU_loss: 0.0284 - TSICU_loss: 0.0202 - CCU_accuracy: 0.9434 - CSRU_accuracy: 0.9429 - MICU_accuracy: 0.9428 - SICU_accuracy: 0.9432 - TSICU_accuracy: 0.9430 - val_loss: 0.8972 - val_CCU_loss: 0.1789 - val_CSRU_loss: 0.1943 - val_MICU_loss: 0.1723 - val_SICU_loss: 0.1748 - val_TSICU_loss: 0.1769 - val_CCU_accuracy: 0.9432 - val_CSRU_accuracy: 0.9429 - val_MICU_accuracy: 0.9429 - val_SICU_accuracy: 0.9429 - val_TSICU_accuracy: 0.9429
# Epoch 13/30
# 214/214 [==============================] - 5s 22ms/step - loss: 0.1618 - CCU_loss: 0.0229 - CSRU_loss: 0.0135 - MICU_loss: 0.0771 - SICU_loss: 0.0281 - TSICU_loss: 0.0202 - CCU_accuracy: 0.9436 - CSRU_accuracy: 0.9429 - MICU_accuracy: 0.9431 - SICU_accuracy: 0.9432 - TSICU_accuracy: 0.9430 - val_loss: 0.9000 - val_CCU_loss: 0.1826 - val_CSRU_loss: 0.1999 - val_MICU_loss: 0.1708 - val_SICU_loss: 0.1725 - val_TSICU_loss: 0.1742 - val_CCU_accuracy: 0.9435 - val_CSRU_accuracy: 0.9429 - val_MICU_accuracy: 0.9429 - val_SICU_accuracy: 0.9429 - val_TSICU_accuracy: 0.9429
# Epoch 14/30
# 214/214 [==============================] - 5s 21ms/step - loss: 0.1604 - CCU_loss: 0.0229 - CSRU_loss: 0.0132 - MICU_loss: 0.0767 - SICU_loss: 0.0278 - TSICU_loss: 0.0197 - CCU_accuracy: 0.9435 - CSRU_accuracy: 0.9429 - MICU_accuracy: 0.9437 - SICU_accuracy: 0.9435 - TSICU_accuracy: 0.9430 - val_loss: 0.8864 - val_CCU_loss: 0.1770 - val_CSRU_loss: 0.1899 - val_MICU_loss: 0.1723 - val_SICU_loss: 0.1743 - val_TSICU_loss: 0.1728 - val_CCU_accuracy: 0.9435 - val_CSRU_accuracy: 0.9429 - val_MICU_accuracy: 0.9432 - val_SICU_accuracy: 0.9425 - val_TSICU_accuracy: 0.9429
# Epoch 15/30
# 214/214 [==============================] - 5s 22ms/step - loss: 0.1591 - CCU_loss: 0.0226 - CSRU_loss: 0.0132 - MICU_loss: 0.0760 - SICU_loss: 0.0277 - TSICU_loss: 0.0197 - CCU_accuracy: 0.9437 - CSRU_accuracy: 0.9429 - MICU_accuracy: 0.9439 - SICU_accuracy: 0.9439 - TSICU_accuracy: 0.9431 - val_loss: 0.8853 - val_CCU_loss: 0.1764 - val_CSRU_loss: 0.1848 - val_MICU_loss: 0.1749 - val_SICU_loss: 0.1771 - val_TSICU_loss: 0.1722 - val_CCU_accuracy: 0.9432 - val_CSRU_accuracy: 0.9429 - val_MICU_accuracy: 0.9425 - val_SICU_accuracy: 0.9425 - val_TSICU_accuracy: 0.9429
# Epoch 16/30
# 214/214 [==============================] - 5s 22ms/step - loss: 0.1581 - CCU_loss: 0.0225 - CSRU_loss: 0.0130 - MICU_loss: 0.0757 - SICU_loss: 0.0276 - TSICU_loss: 0.0194 - CCU_accuracy: 0.9438 - CSRU_accuracy: 0.9430 - MICU_accuracy: 0.9444 - SICU_accuracy: 0.9444 - TSICU_accuracy: 0.9432 - val_loss: 0.8811 - val_CCU_loss: 0.1775 - val_CSRU_loss: 0.1895 - val_MICU_loss: 0.1704 - val_SICU_loss: 0.1721 - val_TSICU_loss: 0.1716 - val_CCU_accuracy: 0.9438 - val_CSRU_accuracy: 0.9429 - val_MICU_accuracy: 0.9429 - val_SICU_accuracy: 0.9429 - val_TSICU_accuracy: 0.9429
# Epoch 17/30
# 214/214 [==============================] - 5s 21ms/step - loss: 0.1568 - CCU_loss: 0.0221 - CSRU_loss: 0.0128 - MICU_loss: 0.0751 - SICU_loss: 0.0274 - TSICU_loss: 0.0194 - CCU_accuracy: 0.9440 - CSRU_accuracy: 0.9432 - MICU_accuracy: 0.9447 - SICU_accuracy: 0.9449 - TSICU_accuracy: 0.9432 - val_loss: 0.8807 - val_CCU_loss: 0.1787 - val_CSRU_loss: 0.1895 - val_MICU_loss: 0.1698 - val_SICU_loss: 0.1717 - val_TSICU_loss: 0.1710 - val_CCU_accuracy: 0.9438 - val_CSRU_accuracy: 0.9429 - val_MICU_accuracy: 0.9429 - val_SICU_accuracy: 0.9432 - val_TSICU_accuracy: 0.9429
# Epoch 18/30
# 214/214 [==============================] - 5s 21ms/step - loss: 0.1557 - CCU_loss: 0.0220 - CSRU_loss: 0.0126 - MICU_loss: 0.0748 - SICU_loss: 0.0271 - TSICU_loss: 0.0192 - CCU_accuracy: 0.9443 - CSRU_accuracy: 0.9435 - MICU_accuracy: 0.9451 - SICU_accuracy: 0.9450 - TSICU_accuracy: 0.9433 - val_loss: 0.8758 - val_CCU_loss: 0.1747 - val_CSRU_loss: 0.1819 - val_MICU_loss: 0.1727 - val_SICU_loss: 0.1751 - val_TSICU_loss: 0.1715 - val_CCU_accuracy: 0.9442 - val_CSRU_accuracy: 0.9432 - val_MICU_accuracy: 0.9425 - val_SICU_accuracy: 0.9432 - val_TSICU_accuracy: 0.9429
# Epoch 19/30
# 214/214 [==============================] - 5s 22ms/step - loss: 0.1545 - CCU_loss: 0.0217 - CSRU_loss: 0.0125 - MICU_loss: 0.0739 - SICU_loss: 0.0271 - TSICU_loss: 0.0192 - CCU_accuracy: 0.9441 - CSRU_accuracy: 0.9434 - MICU_accuracy: 0.9452 - SICU_accuracy: 0.9452 - TSICU_accuracy: 0.9434 - val_loss: 0.8797 - val_CCU_loss: 0.1796 - val_CSRU_loss: 0.1881 - val_MICU_loss: 0.1697 - val_SICU_loss: 0.1721 - val_TSICU_loss: 0.1702 - val_CCU_accuracy: 0.9445 - val_CSRU_accuracy: 0.9432 - val_MICU_accuracy: 0.9432 - val_SICU_accuracy: 0.9438 - val_TSICU_accuracy: 0.9429
# Epoch 20/30
# 214/214 [==============================] - 5s 22ms/step - loss: 0.1534 - CCU_loss: 0.0215 - CSRU_loss: 0.0123 - MICU_loss: 0.0736 - SICU_loss: 0.0268 - TSICU_loss: 0.0191 - CCU_accuracy: 0.9448 - CSRU_accuracy: 0.9437 - MICU_accuracy: 0.9455 - SICU_accuracy: 0.9458 - TSICU_accuracy: 0.9436 - val_loss: 0.8803 - val_CCU_loss: 0.1798 - val_CSRU_loss: 0.1884 - val_MICU_loss: 0.1704 - val_SICU_loss: 0.1715 - val_TSICU_loss: 0.1702 - val_CCU_accuracy: 0.9442 - val_CSRU_accuracy: 0.9432 - val_MICU_accuracy: 0.9442 - val_SICU_accuracy: 0.9445 - val_TSICU_accuracy: 0.9432
# Epoch 21/30
# 214/214 [==============================] - 5s 22ms/step - loss: 0.1525 - CCU_loss: 0.0213 - CSRU_loss: 0.0121 - MICU_loss: 0.0731 - SICU_loss: 0.0268 - TSICU_loss: 0.0191 - CCU_accuracy: 0.9454 - CSRU_accuracy: 0.9442 - MICU_accuracy: 0.9459 - SICU_accuracy: 0.9463 - TSICU_accuracy: 0.9438 - val_loss: 0.8714 - val_CCU_loss: 0.1756 - val_CSRU_loss: 0.1785 - val_MICU_loss: 0.1721 - val_SICU_loss: 0.1754 - val_TSICU_loss: 0.1698 - val_CCU_accuracy: 0.9442 - val_CSRU_accuracy: 0.9432 - val_MICU_accuracy: 0.9429 - val_SICU_accuracy: 0.9435 - val_TSICU_accuracy: 0.9442
# Epoch 22/30
# 214/214 [==============================] - 5s 21ms/step - loss: 0.1516 - CCU_loss: 0.0214 - CSRU_loss: 0.0120 - MICU_loss: 0.0728 - SICU_loss: 0.0266 - TSICU_loss: 0.0188 - CCU_accuracy: 0.9455 - CSRU_accuracy: 0.9445 - MICU_accuracy: 0.9463 - SICU_accuracy: 0.9469 - TSICU_accuracy: 0.9442 - val_loss: 0.8866 - val_CCU_loss: 0.1848 - val_CSRU_loss: 0.1930 - val_MICU_loss: 0.1686 - val_SICU_loss: 0.1697 - val_TSICU_loss: 0.1704 - val_CCU_accuracy: 0.9445 - val_CSRU_accuracy: 0.9435 - val_MICU_accuracy: 0.9442 - val_SICU_accuracy: 0.9445 - val_TSICU_accuracy: 0.9445
# Epoch 23/30
# 214/214 [==============================] - 5s 21ms/step - loss: 0.1511 - CCU_loss: 0.0212 - CSRU_loss: 0.0119 - MICU_loss: 0.0725 - SICU_loss: 0.0266 - TSICU_loss: 0.0188 - CCU_accuracy: 0.9457 - CSRU_accuracy: 0.9448 - MICU_accuracy: 0.9465 - SICU_accuracy: 0.9470 - TSICU_accuracy: 0.9444 - val_loss: 0.8715 - val_CCU_loss: 0.1792 - val_CSRU_loss: 0.1859 - val_MICU_loss: 0.1678 - val_SICU_loss: 0.1701 - val_TSICU_loss: 0.1685 - val_CCU_accuracy: 0.9448 - val_CSRU_accuracy: 0.9435 - val_MICU_accuracy: 0.9445 - val_SICU_accuracy: 0.9455 - val_TSICU_accuracy: 0.9442
# Epoch 24/30
# 214/214 [==============================] - 5s 21ms/step - loss: 0.1495 - CCU_loss: 0.0209 - CSRU_loss: 0.0119 - MICU_loss: 0.0718 - SICU_loss: 0.0262 - TSICU_loss: 0.0186 - CCU_accuracy: 0.9461 - CSRU_accuracy: 0.9449 - MICU_accuracy: 0.9466 - SICU_accuracy: 0.9470 - TSICU_accuracy: 0.9446 - val_loss: 0.8750 - val_CCU_loss: 0.1813 - val_CSRU_loss: 0.1874 - val_MICU_loss: 0.1676 - val_SICU_loss: 0.1700 - val_TSICU_loss: 0.1687 - val_CCU_accuracy: 0.9445 - val_CSRU_accuracy: 0.9438 - val_MICU_accuracy: 0.9445 - val_SICU_accuracy: 0.9458 - val_TSICU_accuracy: 0.9445
# Epoch 25/30
# 214/214 [==============================] - 5s 21ms/step - loss: 0.1490 - CCU_loss: 0.0210 - CSRU_loss: 0.0117 - MICU_loss: 0.0716 - SICU_loss: 0.0262 - TSICU_loss: 0.0186 - CCU_accuracy: 0.9457 - CSRU_accuracy: 0.9450 - MICU_accuracy: 0.9468 - SICU_accuracy: 0.9473 - TSICU_accuracy: 0.9450 - val_loss: 0.8748 - val_CCU_loss: 0.1810 - val_CSRU_loss: 0.1867 - val_MICU_loss: 0.1680 - val_SICU_loss: 0.1705 - val_TSICU_loss: 0.1686 - val_CCU_accuracy: 0.9442 - val_CSRU_accuracy: 0.9438 - val_MICU_accuracy: 0.9448 - val_SICU_accuracy: 0.9461 - val_TSICU_accuracy: 0.9452
# INFO:tensorflow:Assets written to: ../data/models/model_multitask_48+24_careunits/assets
#     ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#     Predicting using 'multitask' model...
# 191/191 [==============================] - 1s 4ms/step
#     Done!
# CPU times: user 2min 21s, sys: 12.8 s, total: 2min 34s
# Wall time: 2min 33s

# %%
metrics_mtl_48_careunits_df
# Out:
#             AUC       PPV  Specificity
# CCU    0.843639  0.180258     0.776869
# CSRU   0.908939  0.150685     0.953383
# MICU   0.826925  0.178660     0.652493
# SICU   0.866575  0.175258     0.734807
# TSICU  0.833721  0.151832     0.782550
# Macro  0.855960  0.167339     0.780021
# Micro  0.861704  0.173777     0.770597

# %% [markdown]
# Now, let's repeat the prediction task but this time using the groups fetched in an unsupervised way from step 1 proposed by the authors in the paper:

# %%
# %%time
metrics_mtl_48_unsupervised_df = run_mortality_prediction_task(model_type='multitask', cutoff_hours=48, gap_hours=24,
                                                               cohort_criteria_to_select='unsupervised', cohort_unsupervised_filename='../data/unsupervised_clusters_48.npy')
# Out:
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Preparing the data
# --------------------------------------------------------------------------------
#     Loading data from MIMIC-Extract pipeline...
#     Adding SAPS II score to static dataset...
#     Adding mortality columns to static dataset...
#     Discretizing X...
#         X.shape: (2200954, 33), X.subject_id.nunique(): 34472
#         X_discrete.shape: (2200954, 225), X_discrete.subject_id.nunique(): 34472
#     Keep only X_discrete[X_discrete.hours_in < 48]...
#         New X_discrete.shape: (1349653, 223), new X_discrete.subject_id.nunique(): 34472
#     Padding patients with less than 48 hours of data...
#     Merging dataframes to create X_full...
#     Mortality per careunit...
#         MICU: 866 out of 10409
#         SICU: 303 out of 4815
#         CCU: 258 out of 4403
#         CSRU: 110 out of 6865
#         TSICU: 202 out of 3950
#     Final shape of X: (30442, 48, 232)
#     Number of positive samples: 1739
#     Done!
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Running the Mortality Prediction Task
# --------------------------------------------------------------------------------
#     Splitting data into train/validation/test sets...
#     Calculating number of training samples in cohort...
#         # of patients in cohort 0 is 9125
#         # of patients in cohort 1 is 12183
#     ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#     Training 'multitask' model...
# Model: "multitask_learning_model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input (InputLayer)             [(None, 48, 232)]    0           []
#
#  lstm (LSTM)                    (None, 16)           15936       ['input[0][0]']
#
#  0 (Dense)                      (None, 1)            17          ['lstm[0][0]']
#
#  1 (Dense)                      (None, 1)            17          ['lstm[0][0]']
#
# ==================================================================================================
# Total params: 15,970
# Trainable params: 15,970
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None
# Epoch 1/30
# 214/214 [==============================] - 6s 22ms/step - loss: 0.4679 - 0_loss: 0.2007 - 1_loss: 0.2672 - 0_accuracy: 0.9256 - 1_accuracy: 0.9266 - val_loss: 0.6930 - val_0_loss: 0.3697 - val_1_loss: 0.3233 - val_0_accuracy: 0.9429 - val_1_accuracy: 0.9422
# Epoch 2/30
# 214/214 [==============================] - 5s 21ms/step - loss: 0.2684 - 0_loss: 0.1198 - 1_loss: 0.1486 - 0_accuracy: 0.9429 - 1_accuracy: 0.9428 - val_loss: 0.5293 - val_0_loss: 0.2942 - val_1_loss: 0.2351 - val_0_accuracy: 0.9429 - val_1_accuracy: 0.9429
# Epoch 3/30
# 214/214 [==============================] - 5s 21ms/step - loss: 0.2200 - 0_loss: 0.0886 - 1_loss: 0.1314 - 0_accuracy: 0.9429 - 1_accuracy: 0.9428 - val_loss: 0.4640 - val_0_loss: 0.2486 - val_1_loss: 0.2154 - val_0_accuracy: 0.9429 - val_1_accuracy: 0.9429
# Epoch 4/30
# 214/214 [==============================] - 5s 21ms/step - loss: 0.2023 - 0_loss: 0.0749 - 1_loss: 0.1274 - 0_accuracy: 0.9429 - 1_accuracy: 0.9427 - val_loss: 0.4199 - val_0_loss: 0.2174 - val_1_loss: 0.2025 - val_0_accuracy: 0.9429 - val_1_accuracy: 0.9429
# Epoch 5/30
# 214/214 [==============================] - 5s 21ms/step - loss: 0.1893 - 0_loss: 0.0671 - 1_loss: 0.1222 - 0_accuracy: 0.9428 - 1_accuracy: 0.9428 - val_loss: 0.3955 - val_0_loss: 0.1970 - val_1_loss: 0.1986 - val_0_accuracy: 0.9429 - val_1_accuracy: 0.9429
# Epoch 6/30
# 214/214 [==============================] - 4s 21ms/step - loss: 0.1819 - 0_loss: 0.0629 - 1_loss: 0.1189 - 0_accuracy: 0.9427 - 1_accuracy: 0.9428 - val_loss: 0.3792 - val_0_loss: 0.1877 - val_1_loss: 0.1915 - val_0_accuracy: 0.9425 - val_1_accuracy: 0.9429
# Epoch 7/30
# 214/214 [==============================] - 4s 21ms/step - loss: 0.1776 - 0_loss: 0.0611 - 1_loss: 0.1165 - 0_accuracy: 0.9430 - 1_accuracy: 0.9426 - val_loss: 0.3732 - val_0_loss: 0.1874 - val_1_loss: 0.1858 - val_0_accuracy: 0.9429 - val_1_accuracy: 0.9429
# Epoch 8/30
# 214/214 [==============================] - 4s 21ms/step - loss: 0.1743 - 0_loss: 0.0594 - 1_loss: 0.1150 - 0_accuracy: 0.9431 - 1_accuracy: 0.9427 - val_loss: 0.3682 - val_0_loss: 0.1836 - val_1_loss: 0.1846 - val_0_accuracy: 0.9429 - val_1_accuracy: 0.9429
# Epoch 9/30
# 214/214 [==============================] - 5s 21ms/step - loss: 0.1721 - 0_loss: 0.0581 - 1_loss: 0.1140 - 0_accuracy: 0.9431 - 1_accuracy: 0.9427 - val_loss: 0.3612 - val_0_loss: 0.1798 - val_1_loss: 0.1814 - val_0_accuracy: 0.9429 - val_1_accuracy: 0.9429
# Epoch 10/30
# 214/214 [==============================] - 4s 21ms/step - loss: 0.1699 - 0_loss: 0.0573 - 1_loss: 0.1126 - 0_accuracy: 0.9431 - 1_accuracy: 0.9427 - val_loss: 0.3597 - val_0_loss: 0.1804 - val_1_loss: 0.1792 - val_0_accuracy: 0.9432 - val_1_accuracy: 0.9429
# Epoch 11/30
# 214/214 [==============================] - 5s 22ms/step - loss: 0.1683 - 0_loss: 0.0565 - 1_loss: 0.1118 - 0_accuracy: 0.9432 - 1_accuracy: 0.9428 - val_loss: 0.3533 - val_0_loss: 0.1776 - val_1_loss: 0.1756 - val_0_accuracy: 0.9435 - val_1_accuracy: 0.9429
# Epoch 12/30
# 214/214 [==============================] - 5s 23ms/step - loss: 0.1668 - 0_loss: 0.0559 - 1_loss: 0.1108 - 0_accuracy: 0.9431 - 1_accuracy: 0.9427 - val_loss: 0.3481 - val_0_loss: 0.1741 - val_1_loss: 0.1740 - val_0_accuracy: 0.9438 - val_1_accuracy: 0.9429
# Epoch 13/30
# 214/214 [==============================] - 5s 21ms/step - loss: 0.1652 - 0_loss: 0.0551 - 1_loss: 0.1101 - 0_accuracy: 0.9433 - 1_accuracy: 0.9428 - val_loss: 0.3455 - val_0_loss: 0.1736 - val_1_loss: 0.1719 - val_0_accuracy: 0.9432 - val_1_accuracy: 0.9429
# Epoch 14/30
# 214/214 [==============================] - 5s 23ms/step - loss: 0.1639 - 0_loss: 0.0548 - 1_loss: 0.1091 - 0_accuracy: 0.9427 - 1_accuracy: 0.9428 - val_loss: 0.3411 - val_0_loss: 0.1715 - val_1_loss: 0.1695 - val_0_accuracy: 0.9432 - val_1_accuracy: 0.9429
# Epoch 15/30
# 214/214 [==============================] - 5s 22ms/step - loss: 0.1623 - 0_loss: 0.0541 - 1_loss: 0.1082 - 0_accuracy: 0.9427 - 1_accuracy: 0.9428 - val_loss: 0.3439 - val_0_loss: 0.1747 - val_1_loss: 0.1692 - val_0_accuracy: 0.9422 - val_1_accuracy: 0.9429
# Epoch 16/30
# 214/214 [==============================] - 5s 21ms/step - loss: 0.1611 - 0_loss: 0.0537 - 1_loss: 0.1074 - 0_accuracy: 0.9431 - 1_accuracy: 0.9430 - val_loss: 0.3355 - val_0_loss: 0.1693 - val_1_loss: 0.1662 - val_0_accuracy: 0.9429 - val_1_accuracy: 0.9429
# Epoch 17/30
# 214/214 [==============================] - 5s 22ms/step - loss: 0.1601 - 0_loss: 0.0532 - 1_loss: 0.1069 - 0_accuracy: 0.9424 - 1_accuracy: 0.9430 - val_loss: 0.3358 - val_0_loss: 0.1708 - val_1_loss: 0.1650 - val_0_accuracy: 0.9422 - val_1_accuracy: 0.9429
# Epoch 18/30
# 214/214 [==============================] - 5s 22ms/step - loss: 0.1588 - 0_loss: 0.0530 - 1_loss: 0.1058 - 0_accuracy: 0.9430 - 1_accuracy: 0.9434 - val_loss: 0.3434 - val_0_loss: 0.1773 - val_1_loss: 0.1661 - val_0_accuracy: 0.9399 - val_1_accuracy: 0.9422
# Epoch 19/30
# 214/214 [==============================] - 5s 21ms/step - loss: 0.1579 - 0_loss: 0.0526 - 1_loss: 0.1052 - 0_accuracy: 0.9432 - 1_accuracy: 0.9435 - val_loss: 0.3370 - val_0_loss: 0.1735 - val_1_loss: 0.1635 - val_0_accuracy: 0.9392 - val_1_accuracy: 0.9429
# Epoch 20/30
# 214/214 [==============================] - 5s 22ms/step - loss: 0.1566 - 0_loss: 0.0520 - 1_loss: 0.1045 - 0_accuracy: 0.9426 - 1_accuracy: 0.9436 - val_loss: 0.3360 - val_0_loss: 0.1733 - val_1_loss: 0.1627 - val_0_accuracy: 0.9386 - val_1_accuracy: 0.9429
# INFO:tensorflow:Assets written to: ../data/models/model_multitask_48+24_unsupervised/assets
#     ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#     Predicting using 'multitask' model...
# 191/191 [==============================] - 1s 4ms/step
#     Done!
# CPU times: user 1min 57s, sys: 13 s, total: 2min 10s
# Wall time: 2min 9s

# %%
metrics_mtl_48_unsupervised_df
# Out:
#             AUC       PPV  Specificity
# 0      0.869672  0.164300     0.836053
# 1      0.836839  0.175470     0.714684
# Macro  0.853255  0.169885     0.775368
# Micro  0.853652  0.172050     0.767810
